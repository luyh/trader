# %%
# %matplotlib inline
# %load_ext autoreload

# %autoreload 2
import tensorflow as tf
tf.enable_eager_execution()
tf.executing_eagerly()
# Out:
# True

# %%
# !pip install ../forks/tensortrade_source/ -U
# Out:
# Processing c:\users\codeninja\dev\forks\tensortrade_source
# Requirement already satisfied, skipping upgrade: numpy==1.16.4 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade==0.1.0rc1) (1.16.4)
# Requirement already satisfied, skipping upgrade: pandas==0.25.0 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade==0.1.0rc1) (0.25.0)
# Requirement already satisfied, skipping upgrade: gym==0.14.0 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade==0.1.0rc1) (0.14.0)
# Requirement already satisfied, skipping upgrade: pyyaml==5.1.2 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from tensortrade==0.1.0rc1) (5.1.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pandas==0.25.0->tensortrade==0.1.0rc1) (2.8.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pandas==0.25.0->tensortrade==0.1.0rc1) (2019.3)
# Requirement already satisfied, skipping upgrade: six in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.1.0rc1) (1.12.0)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.1.0rc1) (1.3.1)
# Requirement already satisfied, skipping upgrade: pyglet<=1.3.2,>=1.2.0 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.1.0rc1) (1.3.2)
# Requirement already satisfied, skipping upgrade: cloudpickle~=1.2.0 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.1.0rc1) (1.2.2)
# Requirement already satisfied, skipping upgrade: future in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pyglet<=1.3.2,>=1.2.0->gym==0.14.0->tensortrade==0.1.0rc1) (0.18.1)
# Building wheels for collected packages: tensortrade
#   Building wheel for tensortrade (setup.py): started
#   Building wheel for tensortrade (setup.py): finished with status 'done'
#   Created wheel for tensortrade: filename=tensortrade-0.1.0rc1-cp37-none-any.whl size=73691 sha256=6470c269a352c61029163d859e9b498542ca8dde91a8dca94232c328a2f37ea4
#   Stored in directory: C:\Users\CODENI~1\AppData\Local\Temp\pip-ephem-wheel-cache-4rq7y7iq\wheels\62\be\3a\90782c795f0ba93fec4a55c551ac7e8f7e7ea933797e4f71c0
# Successfully built tensortrade
# Installing collected packages: tensortrade
#   Found existing installation: tensortrade 0.1.0rc1
#     Uninstalling tensortrade-0.1.0rc1:
#       Successfully uninstalled tensortrade-0.1.0rc1
# Successfully installed tensortrade-0.1.0rc1

# %%
import os
import sys
import warnings
import numpy
import ccxt
import pandas as pd
import numpy as np
from time import time
import math
import cProfile as cp
import matplotlib.pyplot as plt
import pickle

from gym.spaces import Space, Box

config = './neat.config'

def warn(*args, **kwargs):
    pass

warnings.warn = warn
warnings.simplefilter(action='ignore', category=FutureWarning)
numpy.seterr(divide = 'ignore') 

sys.path.append(os.path.dirname(os.path.abspath('')))
sys.path.append(os.path.abspath('')+"\\tensortrade")

# %% [markdown]
# **Load Data**

# %%
data_file ='./data/processed/binance/btc_usdt_1h.csv' 
df = pd.read_csv(data_file, index_col=[0])


# number of days we want to pull from the dataframe 
days_of_data = 365

# number of data frames (our DF is in 1h timesteps)
frames = days_of_data * 24 * 5
# frames = len(df)
train_test_percentage = 0.4

x_train = int(frames * (1 - train_test_percentage))
x_test = int(frames - x_train)

df_train = df[-frames:(-x_test - 1)]
df_test = df[-x_test:]
print("Friend Shape", df.shape)
print('train shape', df_train.shape)
print('test shape', df_test.shape)
print('columns', df.columns)
# Out:
# Friend Shape (180236, 12)
# train shape (26279, 12)
# test shape (17520, 12)
# columns Index(['open', 'high', 'low', 'close', 'volume', 'momentum_rsi', 'adx',
#        'adx_long', 'adx_pos', 'adx_neg', 'trend_ema_fast', 'trend_ema_slow'],
#       dtype='object')

# %%
df_test.head()
# Out:
#                          open      high       low     close      volume  \
# index
# 2019-08-28 03:35:00  10148.20  10155.65  10140.00  10140.49  103.707956
# 2019-08-28 03:40:00  10140.74  10148.78  10125.01  10133.83   73.728054
# 2019-08-28 03:45:00  10135.11  10145.87  10120.00  10120.01  102.866752
# 2019-08-28 03:50:00  10120.02  10133.51  10116.34  10120.03   55.034065
# 2019-08-28 03:55:00  10120.03  10130.00  10119.02  10126.17   48.912488
#
#                      momentum_rsi        adx  adx_long    adx_pos    adx_neg  \
# index
# 2019-08-28 03:35:00     34.890237  19.680116  9.632237  15.942283  24.099556
# 2019-08-28 03:40:00     30.560787  19.729527  9.551850  14.434463  27.784685
# 2019-08-28 03:45:00     23.560759  20.578936  9.524416  12.994025  26.944578
# 2019-08-28 03:50:00     23.589984  21.604012  9.514225  12.128909  26.569855
# 2019-08-28 03:55:00     32.704088  22.726318  9.516439  11.597170  25.405014
#
#                      trend_ema_fast  trend_ema_slow
# index
# 2019-08-28 03:35:00    10153.780045    10155.268113
# 2019-08-28 03:40:00    10150.710807    10153.680105
# 2019-08-28 03:45:00    10145.987606    10151.186023
# 2019-08-28 03:50:00    10141.994128    10148.878170
# 2019-08-28 03:55:00    10139.559647    10147.196083

# %% [markdown]
# **Load Previous Winner**

# %%
# winner = "winner-1751.bin"
# with open("winners/{}".format(winner), "rb") as f:
#     winner = pickle.load(f)

# %% [markdown]
# **Train against training data**

# %%
import tensortrade
from neat_trading_strategy import NeatTradingStrategy as TradingStrategy
from neat_reward_strategy import NeatRewardStrategy as ProfitStrategy
from tensortrade.actions import DiscreteActions
from tensortrade.exchanges.simulated import SimulatedExchange as Exchange
from tensortrade.features.scalers import MinMaxNormalizer
from tensortrade.features import FeaturePipeline
from tensortrade.environments import TradingEnvironment as Environment

print('fin imports')
normalize = MinMaxNormalizer(inplace=True)
feature_pipeline = FeaturePipeline(steps=[normalize])

reward_scheme = ProfitStrategy()
action_scheme = DiscreteActions(n_actions=5, instrument='BTC/USDT')
print('fin strats')

exchange = Exchange(data_frame=df_train,
                    pretransform = True,
                    base_instrument='USDT', 
                    commission_percent=0.075,
                    window_size=1,
                    max_allowed_slippage_percent=3.0,
                    min_order_amount=1E-4,
                    min_trade_amount=1E-4,
                    observation_columns = df_train.columns
                   )
print('fin exchange')

environment = Environment(exchange=exchange,
                                 action_scheme=action_scheme,
                                 reward_scheme=reward_scheme,
                                 feature_pipeline=feature_pipeline)
print('fin environment')
print('')

segments_in_day = 288
days = 2

strategy = TradingStrategy(environment=environment,
                           pop_size= 50,
                           initial_connectin='full_nodirect',
                           max_stagnation= 10,
                           neat_config=config, 
                           watch_genome_evaluation=False,
                           only_show_profitable=False,
                           data_frame_window = segments_in_day * days
                          )

print("Running through ", strategy._data_frame_window, ' steps')
# cp.run("performance, winner, stats = strategy.run(generations=20)", 'evolution_stats')
performance, winner, stats = strategy.run(generations=50)
# Out:
# fin imports
# fin strats
# fin exchange
# fin environment
#
# <neat.config.Config object at 0x000002B7451EDD08>
# Running through  576  steps
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.80000 stdev: 0.40000
# Best fitness: 1.00000 - size: (13, 181) - species 1 - id 2
# Average adjusted fitness: 0.800
# Mean genetic distance 3.959, standard deviation 0.661
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     5      1.0    0.800     0
# Total extinctions: 0
# Generation time: 7.468 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 288.63811 stdev: 575.77636
# Best fitness: 1440.19056 - size: (13, 171) - species 1 - id 8
# Average adjusted fitness: 0.200
# Mean genetic distance 2.770, standard deviation 1.142
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1     5   1440.2    0.200     0
# Total extinctions: 0
# Generation time: 10.141 sec (8.804 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 292.39893 stdev: 581.24391
# Best fitness: 1454.88141 - size: (13, 171) - species 1 - id 8
# Average adjusted fitness: 0.201
# Mean genetic distance 3.254, standard deviation 1.105
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2     5   1454.9    0.201     0
# Total extinctions: 0
# Generation time: 5.971 sec (7.860 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 303.74921 stdev: 603.30721
# Best fitness: 1510.35101 - size: (13, 171) - species 1 - id 8
# Average adjusted fitness: 0.201
# Mean genetic distance 2.946, standard deviation 1.545
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3     5   1510.4    0.201     0
# Total extinctions: 0
# Generation time: 5.534 sec (7.278 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 329.24393 stdev: 654.54679
# Best fitness: 1638.33375 - size: (13, 171) - species 1 - id 8
# Average adjusted fitness: 0.201
# Mean genetic distance 4.193, standard deviation 2.157
# Population of 5 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4     3   1638.3    0.201     0
#      2    0     2       --       --     0
# Total extinctions: 0
# Generation time: 5.761 sec (6.975 average)
# Saving checkpoint to neat-checkpoint-4
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 285.48462 stdev: 564.07699
# Best fitness: 1413.62505 - size: (13, 171) - species 1 - id 8
# Average adjusted fitness: 0.169
# Mean genetic distance 3.414, standard deviation 2.097
# Population of 5 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5     2   1413.6    0.335     1
#      2    1     3      7.6    0.003     0
# Total extinctions: 0
# Generation time: 5.501 sec (6.729 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 289.35936 stdev: 570.11639
# Best fitness: 1429.58330 - size: (13, 171) - species 1 - id 8
# Average adjusted fitness: 0.252
# Mean genetic distance 3.535, standard deviation 1.956
# Population of 5 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6     3   1429.6    0.502     2
#      2    2     2      6.1    0.003     1
# Total extinctions: 0
# Generation time: 5.590 sec (6.567 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 291.26823 stdev: 573.88353
# Best fitness: 1439.02500 - size: (13, 171) - species 1 - id 8
# Average adjusted fitness: 0.169
# Mean genetic distance 3.332, standard deviation 2.007
# Population of 5 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7     3   1439.0    0.335     3
#      2    3     2      5.1    0.003     2
# Total extinctions: 0
# Generation time: 5.803 sec (6.471 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 324.00151 stdev: 637.94117
# Best fitness: 1599.87317 - size: (13, 171) - species 1 - id 8
# Average adjusted fitness: 0.169
# Mean genetic distance 3.218, standard deviation 1.976
# Population of 5 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8     3   1599.9    0.335     4
#      2    4     2      7.0    0.004     3
# Total extinctions: 0
# Generation time: 5.906 sec (6.408 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 308.27802 stdev: 605.40999
# Best fitness: 1519.08429 - size: (13, 171) - species 1 - id 8
# Average adjusted fitness: 0.170
# Mean genetic distance 3.281, standard deviation 2.131
# Population of 5 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9     3   1519.1    0.337     5
#      2    5     2      7.3    0.002     4
# Total extinctions: 0
# Generation time: 5.820 sec (6.349 average)
# Saving checkpoint to neat-checkpoint-9
#
# Best individual in generation 9 meets fitness threshold - complexity: (13, 171)
#
# Best genome:
# Key: 8
# Fitness: 1519.0842904511169
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-1.0, response=-11.167689754964407, activation=sigmoid, aggregation=mean)
# 	13 DefaultNodeGene(key=13, bias=0.41227538467017716, response=-2.531496336581501, activation=sigmoid, aggregation=product)
# 	14 DefaultNodeGene(key=14, bias=1.0, response=19.24849549272245, activation=sigmoid, aggregation=max)
# 	15 DefaultNodeGene(key=15, bias=1.0, response=-7.269688697652427, activation=sigmoid, aggregation=mean)
# 	16 DefaultNodeGene(key=16, bias=-1.0, response=-16.271019780631292, activation=relu, aggregation=product)
# 	17 DefaultNodeGene(key=17, bias=-0.5659863523711033, response=14.321052960803312, activation=relu, aggregation=min)
# 	18 DefaultNodeGene(key=18, bias=-0.6357573578704372, response=12.16653526951352, activation=relu, aggregation=min)
# 	19 DefaultNodeGene(key=19, bias=0.16971926390312125, response=-4.519669210796724, activation=sigmoid, aggregation=mean)
# 	20 DefaultNodeGene(key=20, bias=-0.5076397966595447, response=-0.675360316793097, activation=sigmoid, aggregation=max)
# 	21 DefaultNodeGene(key=21, bias=-0.31121028220693414, response=-8.105211173754684, activation=sigmoid, aggregation=min)
# 	22 DefaultNodeGene(key=22, bias=-0.08826905563442333, response=0.4229594068245693, activation=sigmoid, aggregation=sum)
# 	23 DefaultNodeGene(key=23, bias=-0.07829314632319065, response=4.177409763533511, activation=relu, aggregation=max)
# 	24 DefaultNodeGene(key=24, bias=0.8267001846317896, response=-6.206758772647804, activation=sigmoid, aggregation=max)
# Connections:
# 	DefaultConnectionGene(key=(-12, 0), weight=0.5501744381350433, enabled=True)
# 	DefaultConnectionGene(key=(-12, 13), weight=-0.5079827656555299, enabled=True)
# 	DefaultConnectionGene(key=(-12, 14), weight=-1.0172672611049611, enabled=True)
# 	DefaultConnectionGene(key=(-12, 15), weight=-0.14159707011239497, enabled=True)
# 	DefaultConnectionGene(key=(-12, 16), weight=-1.9795890388756372, enabled=True)
# 	DefaultConnectionGene(key=(-12, 17), weight=-2.2745396451547326, enabled=True)
# 	DefaultConnectionGene(key=(-12, 18), weight=-0.7551019084245757, enabled=True)
# 	DefaultConnectionGene(key=(-12, 19), weight=0.22157128337955986, enabled=True)
# 	DefaultConnectionGene(key=(-12, 20), weight=0.6459174830848965, enabled=True)
# 	DefaultConnectionGene(key=(-12, 21), weight=1.2925252302211327, enabled=True)
# 	DefaultConnectionGene(key=(-12, 22), weight=1.2916340049738408, enabled=True)
# 	DefaultConnectionGene(key=(-12, 23), weight=-0.5792775395240108, enabled=True)
# 	DefaultConnectionGene(key=(-12, 24), weight=-1.5708030624916387, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=-0.03706878031167282, enabled=True)
# 	DefaultConnectionGene(key=(-11, 13), weight=0.8516838642505503, enabled=True)
# 	DefaultConnectionGene(key=(-11, 14), weight=-0.7010601209060114, enabled=True)
# 	DefaultConnectionGene(key=(-11, 15), weight=-0.6075283853793023, enabled=True)
# 	DefaultConnectionGene(key=(-11, 16), weight=0.13715447692525187, enabled=True)
# 	DefaultConnectionGene(key=(-11, 17), weight=0.4120339526409054, enabled=True)
# 	DefaultConnectionGene(key=(-11, 18), weight=0.6890817747059235, enabled=True)
# 	DefaultConnectionGene(key=(-11, 19), weight=2.1427554933967903, enabled=True)
# 	DefaultConnectionGene(key=(-11, 20), weight=-1.0872906785788037, enabled=True)
# 	DefaultConnectionGene(key=(-11, 21), weight=0.4593844786005233, enabled=True)
# 	DefaultConnectionGene(key=(-11, 22), weight=-2.17077996107542, enabled=True)
# 	DefaultConnectionGene(key=(-11, 23), weight=0.9729163281275297, enabled=True)
# 	DefaultConnectionGene(key=(-11, 24), weight=0.9333828850775919, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=-1.7206490104652896, enabled=True)
# 	DefaultConnectionGene(key=(-10, 13), weight=0.2697134931281202, enabled=True)
# 	DefaultConnectionGene(key=(-10, 14), weight=1.3216976152973061, enabled=True)
# 	DefaultConnectionGene(key=(-10, 15), weight=-0.6546863881453461, enabled=True)
# 	DefaultConnectionGene(key=(-10, 16), weight=0.004011677336822617, enabled=True)
# 	DefaultConnectionGene(key=(-10, 17), weight=1.1547705461039734, enabled=True)
# 	DefaultConnectionGene(key=(-10, 18), weight=0.42764132840806013, enabled=True)
# 	DefaultConnectionGene(key=(-10, 19), weight=-1.099785976357453, enabled=True)
# 	DefaultConnectionGene(key=(-10, 20), weight=-1.8767554700826214, enabled=True)
# 	DefaultConnectionGene(key=(-10, 21), weight=0.7652034438511075, enabled=True)
# 	DefaultConnectionGene(key=(-10, 22), weight=-0.32153773561274723, enabled=True)
# 	DefaultConnectionGene(key=(-10, 23), weight=-1.140574055372698, enabled=True)
# 	DefaultConnectionGene(key=(-10, 24), weight=-1.89882111533, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.40866441043514334, enabled=True)
# 	DefaultConnectionGene(key=(-9, 13), weight=0.11939724425818604, enabled=True)
# 	DefaultConnectionGene(key=(-9, 14), weight=-1.0065910538035114, enabled=True)
# 	DefaultConnectionGene(key=(-9, 15), weight=-1.873491941261042, enabled=True)
# 	DefaultConnectionGene(key=(-9, 16), weight=0.39128307466458623, enabled=True)
# 	DefaultConnectionGene(key=(-9, 17), weight=-0.6875143454534808, enabled=True)
# 	DefaultConnectionGene(key=(-9, 18), weight=1.3118416806583058, enabled=True)
# 	DefaultConnectionGene(key=(-9, 19), weight=0.22257337414660439, enabled=True)
# 	DefaultConnectionGene(key=(-9, 20), weight=0.12281139982660165, enabled=True)
# 	DefaultConnectionGene(key=(-9, 21), weight=1.121664486837227, enabled=True)
# 	DefaultConnectionGene(key=(-9, 22), weight=0.03598442558023113, enabled=True)
# 	DefaultConnectionGene(key=(-9, 23), weight=-1.3880803054077087, enabled=True)
# 	DefaultConnectionGene(key=(-9, 24), weight=-0.22576170320097055, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=0.021798130661348288, enabled=True)
# 	DefaultConnectionGene(key=(-8, 13), weight=0.7445861364292955, enabled=True)
# 	DefaultConnectionGene(key=(-8, 14), weight=0.8527370915122063, enabled=True)
# 	DefaultConnectionGene(key=(-8, 15), weight=0.9193839566498172, enabled=True)
# 	DefaultConnectionGene(key=(-8, 16), weight=-0.5661665237815685, enabled=True)
# 	DefaultConnectionGene(key=(-8, 17), weight=-0.27006250846823154, enabled=True)
# 	DefaultConnectionGene(key=(-8, 18), weight=0.4614847026920304, enabled=True)
# 	DefaultConnectionGene(key=(-8, 19), weight=0.6741986301660811, enabled=True)
# 	DefaultConnectionGene(key=(-8, 20), weight=-0.21113982946853677, enabled=True)
# 	DefaultConnectionGene(key=(-8, 21), weight=1.0786359123469311, enabled=True)
# 	DefaultConnectionGene(key=(-8, 22), weight=1.5228762997807155, enabled=True)
# 	DefaultConnectionGene(key=(-8, 23), weight=-2.5404214218452417, enabled=True)
# 	DefaultConnectionGene(key=(-8, 24), weight=-0.5118645556323544, enabled=False)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.009542526748567232, enabled=True)
# 	DefaultConnectionGene(key=(-7, 13), weight=-0.9525698504911184, enabled=True)
# 	DefaultConnectionGene(key=(-7, 14), weight=-0.6242390759619495, enabled=True)
# 	DefaultConnectionGene(key=(-7, 15), weight=1.0276033548186472, enabled=True)
# 	DefaultConnectionGene(key=(-7, 16), weight=-2.4976409717527566, enabled=True)
# 	DefaultConnectionGene(key=(-7, 17), weight=1.7733805681217603, enabled=True)
# 	DefaultConnectionGene(key=(-7, 18), weight=0.5571063297649977, enabled=True)
# 	DefaultConnectionGene(key=(-7, 19), weight=-0.31289139036212166, enabled=True)
# 	DefaultConnectionGene(key=(-7, 20), weight=1.274412468888814, enabled=True)
# 	DefaultConnectionGene(key=(-7, 21), weight=1.400366418764404, enabled=True)
# 	DefaultConnectionGene(key=(-7, 22), weight=0.24345343590856944, enabled=True)
# 	DefaultConnectionGene(key=(-7, 23), weight=-0.4887079585977653, enabled=True)
# 	DefaultConnectionGene(key=(-7, 24), weight=0.21367837278313068, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=-1.0551453632521073, enabled=True)
# 	DefaultConnectionGene(key=(-6, 13), weight=-0.5472437807339025, enabled=True)
# 	DefaultConnectionGene(key=(-6, 14), weight=0.40096976670217105, enabled=True)
# 	DefaultConnectionGene(key=(-6, 15), weight=-0.2067018310972319, enabled=False)
# 	DefaultConnectionGene(key=(-6, 16), weight=-1.324643860600536, enabled=True)
# 	DefaultConnectionGene(key=(-6, 17), weight=0.2843858446254273, enabled=True)
# 	DefaultConnectionGene(key=(-6, 18), weight=-0.468960679121177, enabled=True)
# 	DefaultConnectionGene(key=(-6, 19), weight=0.487814322300806, enabled=True)
# 	DefaultConnectionGene(key=(-6, 20), weight=-0.15750473054677605, enabled=True)
# 	DefaultConnectionGene(key=(-6, 21), weight=1.247026776509093, enabled=True)
# 	DefaultConnectionGene(key=(-6, 22), weight=-0.4074277515640419, enabled=True)
# 	DefaultConnectionGene(key=(-6, 23), weight=-1.1309390325057396, enabled=True)
# 	DefaultConnectionGene(key=(-6, 24), weight=3.7848621301666796, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=0.33289696215819786, enabled=True)
# 	DefaultConnectionGene(key=(-5, 13), weight=0.7373002309266694, enabled=False)
# 	DefaultConnectionGene(key=(-5, 14), weight=1.2235354737319768, enabled=True)
# 	DefaultConnectionGene(key=(-5, 15), weight=1.1109017196965492, enabled=True)
# 	DefaultConnectionGene(key=(-5, 16), weight=1.2965924304873566, enabled=True)
# 	DefaultConnectionGene(key=(-5, 17), weight=-1.411363232585809, enabled=True)
# 	DefaultConnectionGene(key=(-5, 18), weight=0.5990775063139345, enabled=False)
# 	DefaultConnectionGene(key=(-5, 19), weight=0.6875866414740232, enabled=True)
# 	DefaultConnectionGene(key=(-5, 20), weight=0.43059993199873253, enabled=True)
# 	DefaultConnectionGene(key=(-5, 21), weight=1.1796266488542364, enabled=True)
# 	DefaultConnectionGene(key=(-5, 22), weight=1.2085450486034648, enabled=True)
# 	DefaultConnectionGene(key=(-5, 23), weight=0.12391531408101175, enabled=True)
# 	DefaultConnectionGene(key=(-5, 24), weight=-0.977358962215725, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=1.5242720525335511, enabled=False)
# 	DefaultConnectionGene(key=(-4, 13), weight=-0.08785012637538742, enabled=True)
# 	DefaultConnectionGene(key=(-4, 14), weight=-2.509451212461639, enabled=True)
# 	DefaultConnectionGene(key=(-4, 15), weight=0.7312956572246105, enabled=True)
# 	DefaultConnectionGene(key=(-4, 16), weight=-0.252935605082217, enabled=True)
# 	DefaultConnectionGene(key=(-4, 17), weight=0.6839206549528842, enabled=False)
# 	DefaultConnectionGene(key=(-4, 18), weight=0.6383041182343093, enabled=True)
# 	DefaultConnectionGene(key=(-4, 19), weight=-0.08175480746048347, enabled=True)
# 	DefaultConnectionGene(key=(-4, 20), weight=0.0029064795349514894, enabled=True)
# 	DefaultConnectionGene(key=(-4, 21), weight=-1.4902251387000802, enabled=True)
# 	DefaultConnectionGene(key=(-4, 22), weight=2.838663953668373, enabled=True)
# 	DefaultConnectionGene(key=(-4, 23), weight=0.5507736404684651, enabled=True)
# 	DefaultConnectionGene(key=(-4, 24), weight=1.7542085937067557, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=0.9651575992781495, enabled=True)
# 	DefaultConnectionGene(key=(-3, 13), weight=-1.3396524933246334, enabled=True)
# 	DefaultConnectionGene(key=(-3, 14), weight=0.9692961706484321, enabled=True)
# 	DefaultConnectionGene(key=(-3, 15), weight=-0.4675597336121744, enabled=True)
# 	DefaultConnectionGene(key=(-3, 16), weight=-1.5579377733596838, enabled=True)
# 	DefaultConnectionGene(key=(-3, 17), weight=0.6656864119406077, enabled=True)
# 	DefaultConnectionGene(key=(-3, 18), weight=1.2990642683350047, enabled=True)
# 	DefaultConnectionGene(key=(-3, 19), weight=0.9593823525631716, enabled=True)
# 	DefaultConnectionGene(key=(-3, 20), weight=0.30875715128286957, enabled=True)
# 	DefaultConnectionGene(key=(-3, 21), weight=-0.7106111129675355, enabled=True)
# 	DefaultConnectionGene(key=(-3, 22), weight=-0.8011462440890449, enabled=True)
# 	DefaultConnectionGene(key=(-3, 23), weight=0.09208133878121305, enabled=True)
# 	DefaultConnectionGene(key=(-3, 24), weight=-0.48388984498848425, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.022928988969069808, enabled=True)
# 	DefaultConnectionGene(key=(-2, 13), weight=0.10887752392086812, enabled=True)
# 	DefaultConnectionGene(key=(-2, 14), weight=-0.5762121006109933, enabled=True)
# 	DefaultConnectionGene(key=(-2, 15), weight=3.1356058121991186, enabled=True)
# 	DefaultConnectionGene(key=(-2, 16), weight=0.2930461786448329, enabled=True)
# 	DefaultConnectionGene(key=(-2, 17), weight=1.2416563502830653, enabled=False)
# 	DefaultConnectionGene(key=(-2, 18), weight=-1.72660010740613, enabled=True)
# 	DefaultConnectionGene(key=(-2, 19), weight=-0.39896321231488924, enabled=False)
# 	DefaultConnectionGene(key=(-2, 20), weight=0.6578041456112043, enabled=True)
# 	DefaultConnectionGene(key=(-2, 21), weight=-0.40738203790595107, enabled=True)
# 	DefaultConnectionGene(key=(-2, 22), weight=-2.055573377008272, enabled=True)
# 	DefaultConnectionGene(key=(-2, 23), weight=0.2036325733903369, enabled=True)
# 	DefaultConnectionGene(key=(-2, 24), weight=-1.167775634568472, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=-0.4225456758451798, enabled=True)
# 	DefaultConnectionGene(key=(-1, 13), weight=0.8689104189364353, enabled=True)
# 	DefaultConnectionGene(key=(-1, 14), weight=0.5889395888065527, enabled=True)
# 	DefaultConnectionGene(key=(-1, 15), weight=1.4336813256817083, enabled=True)
# 	DefaultConnectionGene(key=(-1, 16), weight=-0.05570988946150256, enabled=True)
# 	DefaultConnectionGene(key=(-1, 17), weight=-0.09442081315287415, enabled=True)
# 	DefaultConnectionGene(key=(-1, 18), weight=-0.5843024866155286, enabled=True)
# 	DefaultConnectionGene(key=(-1, 19), weight=-0.6894617704975934, enabled=True)
# 	DefaultConnectionGene(key=(-1, 20), weight=-1.1735007328688691, enabled=True)
# 	DefaultConnectionGene(key=(-1, 21), weight=0.47005074039285055, enabled=True)
# 	DefaultConnectionGene(key=(-1, 22), weight=0.3220003719382949, enabled=True)
# 	DefaultConnectionGene(key=(-1, 23), weight=0.24806084288847824, enabled=True)
# 	DefaultConnectionGene(key=(-1, 24), weight=1.6878195734002732, enabled=True)
# 	DefaultConnectionGene(key=(0, 0), weight=0.5537036712089547, enabled=True)
# 	DefaultConnectionGene(key=(13, 0), weight=-1.8089813589092327, enabled=True)
# 	DefaultConnectionGene(key=(13, 13), weight=0.551425081895409, enabled=True)
# 	DefaultConnectionGene(key=(14, 0), weight=1.877005751478781, enabled=True)
# 	DefaultConnectionGene(key=(14, 14), weight=-0.7641990590063206, enabled=True)
# 	DefaultConnectionGene(key=(15, 0), weight=0.2518826233930844, enabled=True)
# 	DefaultConnectionGene(key=(15, 15), weight=-1.1841032263691271, enabled=True)
# 	DefaultConnectionGene(key=(16, 0), weight=1.644168242115856, enabled=True)
# 	DefaultConnectionGene(key=(16, 16), weight=-0.22435700242471532, enabled=True)
# 	DefaultConnectionGene(key=(17, 0), weight=-1.146239169388982, enabled=True)
# 	DefaultConnectionGene(key=(17, 17), weight=-0.3796428557859278, enabled=True)
# 	DefaultConnectionGene(key=(18, 0), weight=0.7429672186459451, enabled=False)
# 	DefaultConnectionGene(key=(18, 18), weight=-0.3265385185061929, enabled=True)
# 	DefaultConnectionGene(key=(19, 0), weight=-0.9855594639001891, enabled=True)
# 	DefaultConnectionGene(key=(19, 19), weight=-0.34125528881231676, enabled=True)
# 	DefaultConnectionGene(key=(20, 0), weight=-1.9286988780871694, enabled=True)
# 	DefaultConnectionGene(key=(20, 20), weight=-0.9929787012604249, enabled=True)
# 	DefaultConnectionGene(key=(21, 0), weight=-0.30298739210374337, enabled=True)
# 	DefaultConnectionGene(key=(21, 21), weight=-0.7979508158300747, enabled=True)
# 	DefaultConnectionGene(key=(22, 0), weight=-2.6114094520230315, enabled=True)
# 	DefaultConnectionGene(key=(22, 22), weight=-0.5396554495544237, enabled=True)
# 	DefaultConnectionGene(key=(23, 0), weight=-1.7310631738793887, enabled=False)
# 	DefaultConnectionGene(key=(23, 23), weight=0.45567540015697616, enabled=True)
# 	DefaultConnectionGene(key=(24, 0), weight=-0.7168136553082243, enabled=True)
# 	DefaultConnectionGene(key=(24, 24), weight=1.3616177469085557, enabled=True)

# %% [markdown]
# **Evaluate against full dataset**

# %%
 _test_data = df_test[-280*14:(-280*10)]
exchange = Exchange(data_frame=_test_data,
                    pretransform = True,
                    base_instrument='USDT', 
                    commission_percent=0.075,
                    window_size=1,
                    max_allowed_slippage_percent=3.0,
                    min_order_amount=1E-4,
                    min_trade_amount=1E-4,
                    observation_columns = df_test.columns
                   )
environment = Environment(exchange=exchange,
                                 action_scheme=action_scheme,
                                 reward_scheme=reward_scheme,
                                 feature_pipeline=feature_pipeline)

environment.reset()
# from neat_trading_strategy import NeatTradingStrategy as TradingStrategy
# exchange.balance = 100000
strategy = strategy = TradingStrategy(environment=environment, 
                           neat_config=config, 
                           watch_genome_evaluation=True,
                           only_show_profitable=False,
                           full_evaluation=True
                          )
# TradingStrategy(environment=environment, watch_genome_evaluation=True, full_evaluation = True, neat_config=config)
# Out:
# <neat.config.Config object at 0x000002B747F39508>

# %%
exchange._balance = 100
print("Starting Worth: {}".format(exchange.net_worth, exchange.balance))
print(exchange.trades)
strategy.eval_genome(winner, strategy._config)
# Out:
# Starting Worth: 100
# Empty DataFrame
# Columns: [step, symbol, type, amount, price]
# Index: []
# ---------------------------
# -------WE DONE!---------
# Genome ID:  8
# Rewards: 1270.027118321826
# Balance: 1182.6900000000003
# Net Worth: 1182.6900000000003
# Steps Completed 1118
# Most common action dict_items([('MARKET_BUY', 559), ('LIMIT_SELL', 559)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 455, <TradeType.LIMIT_SELL: 3>: 455})
# 1270.027118321826

# %%
pd.set_option('display.max_colwidth', -1)

# %%
exchange.performance.tail()
# Out:
#      balance    net_worth  \
# 905  1154.75  1154.750000
# 906  31.88    1163.534972
# 907  1164.20  1164.200000
# 908  40.61    1181.525973
# 909  1182.69  1182.690000
#
#                                                                                                                                          action  \
# 905  11f0003e-0b51-11ea-95c1-d8cb8a39e9e7: TradeType.LIMIT_SELL 0.14261664 units of BTC for 7904.53 each. Total:1128.16 Comission:0.85@0.00075%
# 906  11f186dc-0b51-11ea-a470-d8cb8a39e9e7: TradeType.MARKET_BUY 0.14321139 units of BTC for 7834.76 each. Total:1122.87 Comission:0.84@0.00075
# 907  11f30d80-0b51-11ea-a2a5-d8cb8a39e9e7: TradeType.LIMIT_SELL 0.14321139 units of BTC for 7900.73 each. Total:1132.32 Comission:0.85@0.00075%
# 908  11f4bb2e-0b51-11ea-88c0-d8cb8a39e9e7: TradeType.MARKET_BUY 0.14426963 units of BTC for 7782.32 each. Total:1123.59 Comission:0.84@0.00075
# 909  11f641da-0b51-11ea-b54b-d8cb8a39e9e7: TradeType.LIMIT_SELL 0.14426963 units of BTC for 7910.35 each. Total:1142.08 Comission:0.86@0.00075%
#
#      step
# 905  1114
# 906  1115
# 907  1116
# 908  1117
# 909  1118

# %%
exchange.trades.tail()
# Out:
#      step symbol                  type    amount    price index
# 905  1114  BTC    TradeType.LIMIT_SELL  0.142617  1128.16  open
# 906  1115  BTC    TradeType.MARKET_BUY  0.143211  1122.87  open
# 907  1116  BTC    TradeType.LIMIT_SELL  0.143211  1132.32  open
# 908  1117  BTC    TradeType.MARKET_BUY  0.144270  1123.59  open
# 909  1118  BTC    TradeType.LIMIT_SELL  0.144270  1142.08  open

# %%
ax = plt.subplot(211)
exchange.performance.net_worth.plot(figsize=(22,8), label='net worth', title='Net Worth')
exchange.performance['com'] = exchange.trades.price*0.00075
ax2 = plt.subplot(212, sharex=ax)
exchange.performance.com.plot(title='Commissions')
plt.legend()

# %%
wins = 0
losses = 0 
ax = plt.subplot(311)

exchange._price_history.plot(figsize=(22,8), label='actual price')
print(_test_data.columns)
_test_data.trend_ema_fast.plot(label='fast ema')
_test_data.trend_ema_slow.plot(label='slow ema')

# print(exchange._price_history.head())
# print(exchange.trades.head())
# print(exchange.performance.head())
for idx,trade in exchange.trades.iterrows():
    price_at_trade = exchange._price_history[trade.step-1]
    if trade.type.is_buy:
        plt.plot(trade.step-1 , price_at_trade, "b^")
    elif trade.type.is_sell:
        the_buy_step = exchange.trades.iloc[idx-1]
        profit = trade.price - the_buy_step.price
        if profit < 0:
            losses +=1
            color = '#d62728'
            plt.axvspan(the_buy_step.step-1, trade.step-1, alpha= 0.5, facecolor='red')
            plt.plot(trade.step-1, price_at_trade, "rD")

        elif profit >= 0:
            wins +=1
            color = '#2ca02c'
            plt.axvspan(the_buy_step.step-1, trade.step-1, alpha= 0.5, facecolor='green')
            plt.plot(trade.step-1, price_at_trade, "gD")

adx = plt.subplot(312, sharex=ax)
_test_data.adx.plot(label='adx')
_test_data.adx_pos.plot(label='pos')
_test_data.adx_neg.plot(label='neg')
_test_data.adx_long.plot(label='long')

_test_data.momentum_rsi.plot(label='rsi')

ax2 = plt.subplot(313, sharex=adx)
exchange.performance.net_worth.plot(title='Net Worth')
ax.legend()

print("Wins:{} Losses:{} Win rate {}%".format(wins, losses, (wins/(wins+losses))*100 ))
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'momentum_rsi', 'adx',
#        'adx_long', 'adx_pos', 'adx_neg', 'trend_ema_fast', 'trend_ema_slow'],
#       dtype='object')
# Wins:281 Losses:174 Win rate 61.75824175824176%

# %%
# Out:
# 281 174 455.0
# 'Win rate 61.75824175824176%'

# %%
import visualize

visualize.plot_stats(stats, ylog=False, view=True)

# %%
visualize.plot_species(stats, view=True)

# %%
visualize.draw_net(strategy._config, winner, False)

# %% [markdown]
# **Save Strategy**

# %%
# winner.key
with open("winners/winner-{}.bin".format(winner.key), "wb") as f:
    pickle.dump(winner, f, 2)
with open("winners/winner-{}_bak.bin".format(winner.key), "wb") as f:
    pickle.dump(winner, f, 2)
