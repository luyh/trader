# %%
# !pip install tensortrade -U
# !pip install neat-python -U
# !pip install tensortrade[tensorforce] -U --user
# Out:
# Requirement already up-to-date: tensortrade in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (0.0.1a18)
# Requirement already satisfied, skipping upgrade: numpy==1.16.4 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade) (1.16.4)
# Requirement already satisfied, skipping upgrade: pandas==0.25.0 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade) (0.25.0)
# Requirement already satisfied, skipping upgrade: gym==0.14.0 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade) (0.14.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pandas==0.25.0->tensortrade) (2019.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pandas==0.25.0->tensortrade) (2.8.0)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade) (1.3.1)
# Requirement already satisfied, skipping upgrade: cloudpickle~=1.2.0 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade) (1.2.2)
# Requirement already satisfied, skipping upgrade: six in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade) (1.12.0)
# Requirement already satisfied, skipping upgrade: pyglet<=1.3.2,>=1.2.0 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade) (1.3.2)
# Requirement already satisfied, skipping upgrade: future in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pyglet<=1.3.2,>=1.2.0->gym==0.14.0->tensortrade) (0.18.1)

# %%
import tensorflow as tf
tf.enable_eager_execution()
tf.executing_eagerly()
# Out:
# True

# %%
import os
import sys
import warnings
import numpy
import ccxt
import pandas as pd
import numpy as np
from time import time

import cProfile as cp


config = './neat.config'

def warn(*args, **kwargs):
    pass

warnings.warn = warn
warnings.simplefilter(action='ignore', category=FutureWarning)
numpy.seterr(divide = 'ignore') 

sys.path.append(os.path.dirname(os.path.abspath('')))
sys.path.append(os.path.abspath('')+"\tensortrade")
# Out:
# 'C:\\Users\\codeninja\\Dev\\trader'

# %% [markdown]
# **Import dataframe**

# %%
# number of days we want to pull from the dataframe 
days_of_data = 1

# number of data frames (our DF is in 1h timesteps)
frames = days_of_data * 24
train_test_percentage = 0.2

x_train = int(frames * (1 - train_test_percentage))
x_test = int(frames - x_train)

# %%
data_file ='./data/processed/binance/btc_usdt_1h.csv' 
df = pd.read_csv(data_file, index_col=[0])
# df.insert(0, column='symbol', value='BTC/USDT')

df_train = df[-frames:(-x_test - 1)]
df_test = df[-x_test:]
print("Friend Shape", df.shape)
print('train shape', df_train.shape)
print('test shape', df_test.shape)
df.head()
# Out:
# Friend Shape (585, 6)
# train shape (18, 6)
# test shape (5, 6)
#                        symbol     open     high      low    close       volume
# 2019-09-30 07:00:00  BTC/USDT  7986.86  8014.21  7984.26  7998.49   269.915958
# 2019-09-30 08:00:00  BTC/USDT  7997.94  8152.80  7997.91  8114.76  4459.172673
# 2019-09-30 09:00:00  BTC/USDT  8114.99  8257.00  8090.42  8201.57  3209.899291
# 2019-09-30 10:00:00  BTC/USDT  8201.54  8300.00  8200.26  8283.85  5111.200055
# 2019-09-30 11:00:00  BTC/USDT  8284.01  8337.26  8232.05  8260.01  2893.741582

# %%
from tensortrade.strategies import NeatTradingStrategy as TradingStrategy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-762159410c72> in <module>
# ----> 1 from tensortrade.strategies import NeatTradingStrategy as TradingStrategy
#
# ImportError: cannot import name 'NeatTradingStrategy' from 'tensortrade.strategies' (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\strategies\__init__.py)

# %%
from tensortrade.rewards import SimpleProfitStrategy as ProfitStrategy
from tensortrade.actions import DiscreteActionStrategy as ActionStrategy
from tensortrade.exchanges.simulated import SimulatedExchange as Exchange
from tensortrade.features.scalers import MinMaxNormalizer
from tensortrade.features import FeaturePipeline

normalize = MinMaxNormalizer(columns=['open','close','high','low','volume'], inplace=True)

feature_pipeline = FeaturePipeline(steps=[normalize])

reward_strategy = ProfitStrategy()
action_strategy = ActionStrategy(n_actions=20, instrument_symbol='BTC/USDT')

exchange = Exchange(data_frame=df_test,
                    should_pretransform_obs = True,
                    base_instrument='USDT', 
                    timeframe='1h',
                    commission_percent=0.5,
                    window_size=1,
                    max_allowed_slippage_percent=3.0,
                    min_order_amount=1E-4,
                    min_trade_amount=1E-4
                   )

# %%
from tensortrade.environments import TradingEnvironment as Environment

environment = Environment(exchange=exchange,
                                 action_strategy=action_strategy,
                                 reward_strategy=reward_strategy,
                                 feature_pipeline=feature_pipeline)


strategy = TradingStrategy(environment=environment, neat_config=config)

# %%
cp.run("performance, winner, stats = strategy.run(generations=20)", 'evolution_stats')
# Out:
#  ****** Running generation 0 ******
#
# *
# *** PROFILER RESULTS ***
# reset (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:205)
# function called 1 times
#
#          10356 function calls (10243 primitive calls) in 0.009 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 483 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.009    0.009 trading_environment.py:205(reset)
#         1    0.000    0.000    0.008    0.008 simulated_exchange.py:211(reset)
#         4    0.000    0.000    0.008    0.002 frame.py:396(__init__)
#         2    0.000    0.000    0.008    0.004 construction.py:216(init_dict)
#         2    0.000    0.000    0.002    0.001 indexing.py:196(__setitem__)
#         2    0.000    0.000    0.002    0.001 indexing.py:165(_get_setitem_indexer)
#         2    0.000    0.000    0.002    0.001 indexing.py:1191(_convert_to_indexer)
#         2    0.000    0.000    0.002    0.001 construction.py:69(arrays_to_mgr)
#         2    0.000    0.000    0.001    0.001 base.py:2881(get_loc)
#         2    0.000    0.000    0.001    0.001 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         2    0.000    0.000    0.001    0.001 series.py:1587(__repr__)
#      10/8    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         1    0.000    0.000    0.001    0.001 profilehooks.py:239(new_fn)
#         1    0.000    0.000    0.001    0.001 profilehooks.py:338(__call__)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#         2    0.000    0.000    0.001    0.001 series.py:1617(to_string)
#         3    0.000    0.000    0.001    0.000 managers.py:353(apply)
#         2    0.000    0.000    0.001    0.001 format.py:302(to_string)
#        13    0.000    0.000    0.001    0.000 construction.py:630(sanitize_array)
#      1801    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#       8/6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         2    0.000    0.000    0.001    0.000 series.py:1061(__getitem__)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#        19    0.000    0.000    0.001    0.000 blocks.py:3239(make_block)
#         2    0.000    0.000    0.001    0.000 managers.py:1690(create_block_manager_from_arrays)
#        26    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#        18    0.000    0.000    0.001    0.000 missing.py:48(isna)
#        18    0.000    0.000    0.001    0.000 missing.py:128(_isna_new)
#       193    0.000    0.000    0.001    0.000 base.py:231(is_dtype)
#        24    0.000    0.000    0.001    0.000 blocks.py:3193(get_block_type)
#         4    0.000    0.000    0.001    0.000 series.py:4047(_reduce)
#         2    0.000    0.000    0.001    0.000 construction.py:300(_homogenize)
#         2    0.000    0.000    0.001    0.000 format.py:296(_get_formatted_values)
#         2    0.000    0.000    0.001    0.000 series.py:320(_init_dict)
#         2    0.000    0.000    0.001    0.000 format.py:958(format_array)
#         8    0.000    0.000    0.001    0.000 missing.py:215(_isna_ndarraylike)
#         4    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9369 function calls (9246 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 430 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 trading_environment.py:182(step)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         1    0.000    0.000    0.005    0.005 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.004    0.001 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         3    0.000    0.000    0.001    0.000 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         6    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#        34    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#      1592    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         2    0.000    0.000    0.000    0.000 blocks.py:398(fillna)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 trading_environment.py:182(step)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         1    0.000    0.000    0.004    0.004 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.004    0.001 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         3    0.000    0.000    0.001    0.000 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#         2    0.000    0.000    0.000    0.000 blocks.py:398(fillna)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.010 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.010    0.010 trading_environment.py:182(step)
#         5    0.000    0.000    0.010    0.002 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.010    0.002 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.008    0.003 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.007    0.001 indexing.py:1396(__getitem__)
#         1    0.000    0.000    0.006    0.006 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.006    0.002 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.005    0.001 indexing.py:1762(_getitem_axis)
#         1    0.000    0.000    0.004    0.004 simulated_exchange.py:184(execute_trade)
#         3    0.000    0.000    0.003    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.003    0.003 discrete_action_strategy.py:49(get_trade)
#         6    0.000    0.000    0.003    0.000 managers.py:1223(reindex_indexer)
#         3    0.000    0.000    0.002    0.001 indexing.py:1421(_getbool_axis)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         3    0.000    0.000    0.002    0.001 generic.py:3525(take)
#         3    0.000    0.000    0.002    0.001 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.002    0.001 generic.py:4553(_reindex_with_indexers)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#      1578    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         2    0.000    0.000    0.001    0.000 blocks.py:398(fillna)
#         3    0.000    0.000    0.001    0.000 base.py:3357(reindex)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.008 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.008    0.008 trading_environment.py:182(step)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         1    0.000    0.000    0.005    0.005 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.005    0.002 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         3    0.000    0.000    0.002    0.001 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         2    0.000    0.000    0.001    0.000 blocks.py:398(fillna)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#
#
# *
# *** PROFILER RESULTS ***
# reset (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:205)
# function called 1 times
#
#          10356 function calls (10243 primitive calls) in 0.008 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 483 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.008    0.008 trading_environment.py:205(reset)
#         1    0.000    0.000    0.007    0.007 simulated_exchange.py:211(reset)
#         4    0.000    0.000    0.007    0.002 frame.py:396(__init__)
#         2    0.000    0.000    0.007    0.004 construction.py:216(init_dict)
#         2    0.000    0.000    0.002    0.001 indexing.py:196(__setitem__)
#         2    0.000    0.000    0.002    0.001 indexing.py:165(_get_setitem_indexer)
#         2    0.000    0.000    0.002    0.001 construction.py:69(arrays_to_mgr)
#         2    0.000    0.000    0.002    0.001 indexing.py:1191(_convert_to_indexer)
#         2    0.000    0.000    0.001    0.001 base.py:2881(get_loc)
#      10/8    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         2    0.000    0.000    0.001    0.001 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         2    0.000    0.000    0.001    0.001 series.py:1587(__repr__)
#         2    0.000    0.000    0.001    0.001 series.py:1617(to_string)
#         1    0.000    0.000    0.001    0.001 profilehooks.py:239(new_fn)
#         1    0.000    0.000    0.001    0.001 profilehooks.py:338(__call__)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#         3    0.000    0.000    0.001    0.000 managers.py:353(apply)
#         2    0.000    0.000    0.001    0.000 format.py:302(to_string)
#        13    0.000    0.000    0.001    0.000 construction.py:630(sanitize_array)
#      1801    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.001    0.000 series.py:1061(__getitem__)
#       8/6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#        19    0.000    0.000    0.001    0.000 blocks.py:3239(make_block)
#         2    0.000    0.000    0.001    0.000 managers.py:1690(create_block_manager_from_arrays)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         2    0.000    0.000    0.001    0.000 construction.py:300(_homogenize)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#        24    0.000    0.000    0.001    0.000 blocks.py:3193(get_block_type)
#        26    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#       193    0.000    0.000    0.001    0.000 base.py:231(is_dtype)
#        18    0.000    0.000    0.001    0.000 missing.py:48(isna)
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#        18    0.000    0.000    0.001    0.000 missing.py:128(_isna_new)
#        13    0.000    0.000    0.001    0.000 construction.py:759(_try_cast)
#         2    0.000    0.000    0.001    0.000 series.py:320(_init_dict)
#         2    0.000    0.000    0.001    0.000 format.py:296(_get_formatted_values)
#         2    0.000    0.000    0.001    0.000 managers.py:1725(form_blocks)
#         8    0.000    0.000    0.001    0.000 missing.py:215(_isna_ndarraylike)
#         2    0.000    0.000    0.001    0.000 format.py:958(format_array)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 trading_environment.py:182(step)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         1    0.000    0.000    0.004    0.004 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.004    0.001 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         3    0.000    0.000    0.001    0.000 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#         2    0.000    0.000    0.001    0.000 blocks.py:398(fillna)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 trading_environment.py:182(step)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         1    0.000    0.000    0.004    0.004 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.004    0.001 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         3    0.000    0.000    0.001    0.000 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#         2    0.000    0.000    0.001    0.000 blocks.py:398(fillna)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.008 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.008    0.008 trading_environment.py:182(step)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         3    0.000    0.000    0.005    0.002 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         1    0.000    0.000    0.004    0.004 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         3    0.000    0.000    0.002    0.001 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.002    0.001 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         8    0.000    0.000    0.001    0.000 managers.py:216(_rebuild_blknos_and_blklocs)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 trading_environment.py:182(step)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         3    0.000    0.000    0.004    0.001 indexing.py:789(_getitem_tuple)
#         1    0.000    0.000    0.004    0.004 trading_environment.py:114(_take_action)
#         6    0.000    0.000    0.004    0.001
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#     0.000    0.000    0.001    0.000 construction.py:300(_homogenize)
#         2    0.000    0.000    0.001    0.000 series.py:320(_init_dict)
#         2    0.000    0.000    0.001    0.000 format.py:296(_get_formatted_values)
#         2    0.000    0.000    0.000    0.000 format.py:958(format_array)
#         2    0.000    0.000    0.000    0.000 blocks.py:398(fillna)
#         8    0.000    0.000    0.000    0.000 missing.py:215(_isna_ndarraylike)
#         4    0.000    0.000    0.000    0.000 series.py:4047(_reduce)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 trading_environment.py:182(step)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         1    0.000    0.000    0.004    0.004 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.004    0.001 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         3    0.000    0.000    0.001    0.000 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         2    0.000    0.000    0.001    0.000 blocks.py:398(fillna)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.008 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.008    0.008 trading_environment.py:182(step)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.006    0.001 indexing.py:1396(__getitem__)
#         3    0.000    0.000    0.005    0.002 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         1    0.000    0.000    0.004    0.004 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.003    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         3    0.000    0.000    0.002    0.001 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 indexing.py:1421(_getbool_axis)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#         8    0.000    0.000    0.001    0.000 managers.py:216(_rebuild_blknos_and_blklocs)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 base.py:3357(reindex)
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 trading_environment.py:182(step)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         1    0.000    0.000    0.005    0.005 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.004    0.001 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         3    0.000    0.000    0.001    0.000 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#         2    0.000    0.000    0.001    0.000 blocks.py:398(fillna)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9262 function calls (9141 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 422 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 trading_environment.py:182(step)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.007    0.001 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         1    0.000    0.000    0.004    0.004 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.004    0.001 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         3    0.000    0.000    0.001    0.000 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#         2    0.000    0.000    0.000    0.000 blocks.py:398(fillna)
#
#
# *
# *** PROFILER RESULTS ***
# ...
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#         2    0.000    0.000    0.000    0.000 blocks.py:398(fillna)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9273 function calls (9152 primitive calls) in 0.008 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 426 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.008    0.008 trading_environment.py:182(step)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         1    0.000    0.000    0.005    0.005 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.005    0.002 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         1    0.000    0.000    0.003    0.003 discrete_action_strategy.py:49(get_trade)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         3    0.000    0.000    0.002    0.001 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 base.py:3357(reindex)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9273 function calls (9152 primitive calls) in 0.008 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 426 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.008    0.008 trading_environment.py:182(step)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.006    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.005    0.001 indexing.py:1396(__getitem__)
#         3    0.000    0.000    0.005    0.002 indexing.py:789(_getitem_tuple)
#         6    0.000    0.000    0.004    0.001 indexing.py:1762(_getitem_axis)
#         1    0.000    0.000    0.004    0.004 trading_environment.py:114(_take_action)
#         3    0.000    0.000    0.002    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         1    0.000    0.000    0.002    0.002 simulated_exchange.py:184(execute_trade)
#         3    0.000    0.000    0.002    0.001 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.002    0.001 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#         8    0.001    0.000    0.001    0.000 managers.py:216(_rebuild_blknos_and_blklocs)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 managers.py:1259(<listcomp>)
#
#
#
# *** PROFILER RESULTS ***
# step (C:\Users\codeninja\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py:182)
# function called 1 times
#
#          9273 function calls (9152 primitive calls) in 0.008 seconds
#
#    Ordered by: cumulative time, internal time, call count
#    List reduced from 426 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.008    0.008 trading_environment.py:182(step)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:239(new_fn)
#         5    0.000    0.000    0.008    0.002 profilehooks.py:338(__call__)
#         3    0.000    0.000    0.007    0.002 simulated_exchange.py:143(current_price)
#         6    0.000    0.000    0.006    0.001 indexing.py:1396(__getitem__)
#         3    0.000    0.000    0.005    0.002 indexing.py:789(_getitem_tuple)
#         1    0.000    0.000    0.005    0.005 trading_environment.py:114(_take_action)
#         6    0.000    0.000    0.005    0.001 indexing.py:1762(_getitem_axis)
#         3    0.000    0.000    0.003    0.001 indexing.py:1082(_getitem_iterable)
#         1    0.000    0.000    0.003    0.003 simulated_exchange.py:184(execute_trade)
#         1    0.000    0.000    0.002    0.002 discrete_action_strategy.py:49(get_trade)
#         1    0.000    0.000    0.002    0.002 trading_environment.py:159(_done)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:156(profit_loss_percent)
#         1    0.000    0.000    0.002    0.002 instrument_exchange.py:137(net_worth)
#         6    0.000    0.000    0.002    0.000 managers.py:1223(reindex_indexer)
#         3    0.000    0.000    0.002    0.001 indexing.py:1421(_getbool_axis)
#         3    0.000    0.000    0.001    0.000 indexing.py:1028(_get_listlike_indexer)
#         3    0.000    0.000    0.001    0.000 generic.py:3525(take)
#         3    0.000    0.000    0.001    0.000 generic.py:4553(_reindex_with_indexers)
#         1    0.000    0.000    0.001    0.001 trading_environment.py:130(_next_observation)
#         1    0.000    0.000    0.001    0.001 instrument_exchange.py:181(next_observation)
#         3    0.000    0.000    0.001    0.000 managers.py:1375(take)
#         3    0.000    0.000    0.001    0.000 __init__.py:1126(wrapper)
#        15    0.000    0.000    0.001    0.000 algorithms.py:1608(take_nd)
#         5    0.000    0.000    0.001    0.000 series.py:194(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1273(_slice_take_blocks_ax0)
#        33    0.000    0.000    0.001    0.000 base.py:5697(ensure_index)
#         6    0.000    0.000    0.001    0.000 base.py:2950(get_indexer)
#         8    0.000    0.000    0.001    0.000 managers.py:126(__init__)
#         1    0.000    0.000    0.001    0.001 frame.py:4220(fillna)
#         1    0.000    0.000    0.001    0.001 generic.py:6102(fillna)
#         9    0.000    0.000    0.001    0.000 blocks.py:1292(take_nd)
#         1    0.000    0.000    0.001    0.001 managers.py:574(fillna)
#         1    0.000    0.000    0.001    0.001 managers.py:353(apply)
#      1578    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.001    0.000 base.py:4797(get_indexer_for)
#         6    0.000    0.000    0.001    0.000 base.py:274(__new__)
#         3    0.000    0.000    0.001    0.000 indexing.py:2110(_getitem_axis)
#         3    0.000    0.000    0.001    0.000 base.py:3357(reindex)
#         2    0.000    0.000    0.001    0.000 blocks.py:398(fillna)
#
#
#
# Population's average fitness: 1.25000 stdev: 5.35607
# Best fitness: 8.00000 - size: (7, 44) - species 2 - id 25
# Average adjusted fitness: 0.438
# Mean genetic distance 2.059, standard deviation 1.505
# Population of 4 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19     2      0.5    0.375     5
#      2   19     2      2.0    0.500     2
# Total extinctions: 0
# Generation time: 6.935 sec (7.090 average)
# Saving checkpoint to neat-checkpoint-19
#
# Best individual in generation 19 meets fitness threshold - complexity: (7, 44)
#
# Best genome:
# Key: 25
# Fitness: 8.0
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.06597709257452736, response=1.0, activation=relu, aggregation=median)
# 	6 DefaultNodeGene(key=6, bias=-0.5438930900117726, response=1.0, activation=lelu, aggregation=sum)
# 	7 DefaultNodeGene(key=7, bias=-0.8068630289255886, response=1.0, activation=lelu, aggregation=min)
# 	8 DefaultNodeGene(key=8, bias=0.06314157592733997, response=1.0, activation=lelu, aggregation=min)
# 	9 DefaultNodeGene(key=9, bias=-1.4455572168982866, response=1.0, activation=relu, aggregation=median)
# 	10 DefaultNodeGene(key=10, bias=-0.5762022010539227, response=1.0, activation=lelu, aggregation=mean)
# 	17 DefaultNodeGene(key=17, bias=0.35486275769073133, response=1.0, activation=selu, aggregation=median)
# Connections:
# 	DefaultConnectionGene(key=(-5, 0), weight=-0.8260494317017705, enabled=True)
# 	DefaultConnectionGene(key=(-5, 6), weight=-2.2210238441680046, enabled=True)
# 	DefaultConnectionGene(key=(-5, 7), weight=2.0472475988291245, enabled=True)
# 	DefaultConnectionGene(key=(-5, 8), weight=-0.5904385954391147, enabled=True)
# 	DefaultConnectionGene(key=(-5, 9), weight=-0.3663314900994956, enabled=True)
# 	DefaultConnectionGene(key=(-5, 10), weight=0.5098744009898183, enabled=True)
# 	DefaultConnectionGene(key=(-5, 17), weight=0.785810275093533, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.03320899703085395, enabled=True)
# 	DefaultConnectionGene(key=(-4, 6), weight=-0.7862541206222367, enabled=True)
# 	DefaultConnectionGene(key=(-4, 7), weight=-1.6511633634830145, enabled=True)
# 	DefaultConnectionGene(key=(-4, 8), weight=-0.7051221329907631, enabled=True)
# 	DefaultConnectionGene(key=(-4, 9), weight=1.0480231787936423, enabled=True)
# 	DefaultConnectionGene(key=(-4, 10), weight=-0.10724040029148363, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-0.0025156790572773424, enabled=True)
# 	DefaultConnectionGene(key=(-3, 6), weight=0.1356156958510505, enabled=False)
# 	DefaultConnectionGene(key=(-3, 7), weight=0.6128090610488671, enabled=True)
# 	DefaultConnectionGene(key=(-3, 8), weight=-0.45582505907039705, enabled=True)
# 	DefaultConnectionGene(key=(-3, 9), weight=1.6784064330308004, enabled=True)
# 	DefaultConnectionGene(key=(-3, 10), weight=1.3448509584151256, enabled=True)
# 	DefaultConnectionGene(key=(-3, 17), weight=1.8800552031340831, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=-0.32687995428234873, enabled=True)
# 	DefaultConnectionGene(key=(-2, 6), weight=1.1927331616894288, enabled=True)
# 	DefaultConnectionGene(key=(-2, 7), weight=-0.2683616147573661, enabled=True)
# 	DefaultConnectionGene(key=(-2, 8), weight=-0.3280972922020075, enabled=True)
# 	DefaultConnectionGene(key=(-2, 9), weight=0.15511415123307498, enabled=True)
# 	DefaultConnectionGene(key=(-2, 10), weight=-1.1994674867571131, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=0.5274931236155213, enabled=True)
# 	DefaultConnectionGene(key=(-1, 6), weight=-0.856997296708725, enabled=True)
# 	DefaultConnectionGene(key=(-1, 7), weight=-0.9312429547042802, enabled=True)
# 	DefaultConnectionGene(key=(-1, 8), weight=0.17766978186337457, enabled=True)
# 	DefaultConnectionGene(key=(-1, 9), weight=1.5139394604291438, enabled=True)
# 	DefaultConnectionGene(key=(-1, 10), weight=-0.24624176341962706, enabled=True)
# 	DefaultConnectionGene(key=(0, 0), weight=0.9411878007087744, enabled=True)
# 	DefaultConnectionGene(key=(6, 0), weight=1.4412925242470684, enabled=True)
# 	DefaultConnectionGene(key=(6, 6), weight=-1.1236804450417162, enabled=True)
# 	DefaultConnectionGene(key=(7, 0), weight=0.9596477701763575, enabled=True)
# 	DefaultConnectionGene(key=(7, 7), weight=-0.5147463287106704, enabled=True)
# 	DefaultConnectionGene(key=(8, 0), weight=-2.297251418956951, enabled=True)
# 	DefaultConnectionGene(key=(8, 8), weight=-0.3379256903284043, enabled=True)
# 	DefaultConnectionGene(key=(8, 9), weight=0.11568509557674655, enabled=True)
# 	DefaultConnectionGene(key=(9, 0), weight=0.20185976483425228, enabled=True)
# 	DefaultConnectionGene(key=(9, 9), weight=0.381297551001559, enabled=True)
# 	DefaultConnectionGene(key=(10, 0), weight=-0.5944223593517092, enabled=True)
# 	DefaultConnectionGene(key=(10, 10), weight=-1.2939291297118907, enabled=True)
# 	DefaultConnectionGene(key=(17, 10), weight=1.5586007894512564, enabled=True)

# %%
import pstats
from pstats import SortKey
p = pstats.Stats('evolution_stats')
p.strip_dirs().sort_stats("cumtime").print_stats(20)
# Out:
# Thu Oct 24 13:49:48 2019    evolution_stats
#
#          3277 function calls (3275 primitive calls) in 135.027 seconds
#
#    Ordered by: cumulative time
#    List reduced from 133 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  135.027  135.027 {built-in method builtins.exec}
#         1    0.000    0.000  135.027  135.027 <string>:1(<module>)
#         1    0.000    0.000  135.027  135.027 neat_trading_strategy.py:136(run)
#         1    0.000    0.000  135.025  135.025 population.py:59(run)
#         1    0.000    0.000  135.024  135.024 neat_trading_strategy.py:82(_eval_population)
#         1    0.000    0.000  135.024  135.024 neat_trading_strategy.py:89(eval_genome)
#         1    0.000    0.000  135.023  135.023 profilehooks.py:239(new_fn)
#         1    0.000    0.000  135.023  135.023 profilehooks.py:338(__call__)
#         1    0.000    0.000  135.023  135.023 cProfile.py:106(runcall)
#         1  135.023  135.023  135.023  135.023 {method 'enable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.002    0.001 {built-in method builtins.print}
#         4    0.000    0.000    0.002    0.000 ansitowin32.py:40(write)
#         4    0.000    0.000    0.002    0.000 ansitowin32.py:160(write)
#         4    0.000    0.000    0.002    0.000 ansitowin32.py:177(write_and_convert)
#         4    0.000    0.000    0.002    0.000 ansitowin32.py:193(write_plain_text)
#         3    0.000    0.000    0.002    0.001 iostream.py:336(flush)
#         3    0.000    0.000    0.002    0.001 threading.py:534(wait)
#         3    0.000    0.000    0.002    0.001 threading.py:264(wait)
#         1    0.000    0.000    0.001    0.001 population.py:23(__init__)
#        27    0.001    0.000    0.001    0.000 {method 'acquire' of '_thread.lock' objects}

# %%
exchange.trades
# Out:
# Empty DataFrame
# Columns: [step, symbol, type, amount, price]
# Index: []

# %% [markdown]
# **Evaluate**

# %% [markdown]
# **Save Strategy**

# %%
import visualize

node_names = {-1:'Open', -2: 'High', -3: "Low", -4: "Close", -5:"Volume", 0:'Action'}
visualize.plot_stats(stats, ylog=False, view=True)

# %%
visualize.plot_species(stats, view=True)

# %%
visualize.draw_net(strategy._config, winner, False, node_names=node_names)
