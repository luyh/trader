# %%
# %matplotlib inline
# %load_ext autoreload

# %autoreload 2
import tensorflow as tf
tf.enable_eager_execution()
tf.executing_eagerly()
# Out:
# True

# %%
# !pip install ../forks/tensortrade_source/ -U
# Out:
# Processing c:\users\codeninja\dev\forks\tensortrade_source
# Requirement already satisfied, skipping upgrade: numpy==1.16.4 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade==0.0.2rc0) (1.16.4)
# Requirement already satisfied, skipping upgrade: pandas==0.25.0 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade==0.0.2rc0) (0.25.0)
# Requirement already satisfied, skipping upgrade: gym==0.14.0 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade==0.0.2rc0) (0.14.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pandas==0.25.0->tensortrade==0.0.2rc0) (2.8.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pandas==0.25.0->tensortrade==0.0.2rc0) (2019.3)
# Requirement already satisfied, skipping upgrade: pyglet<=1.3.2,>=1.2.0 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.0.2rc0) (1.3.2)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.0.2rc0) (1.3.1)
# Requirement already satisfied, skipping upgrade: six in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.0.2rc0) (1.12.0)
# Requirement already satisfied, skipping upgrade: cloudpickle~=1.2.0 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.0.2rc0) (1.2.2)
# Requirement already satisfied, skipping upgrade: future in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pyglet<=1.3.2,>=1.2.0->gym==0.14.0->tensortrade==0.0.2rc0) (0.18.1)
# Building wheels for collected packages: tensortrade
#   Building wheel for tensortrade (setup.py): started
#   Building wheel for tensortrade (setup.py): finished with status 'done'
#   Created wheel for tensortrade: filename=tensortrade-0.0.2rc0-cp37-none-any.whl size=56841 sha256=47ee2b1967774de87597865fb80f646beb96cde9ef30327e04441ea37fe60081
#   Stored in directory: C:\Users\CODENI~1\AppData\Local\Temp\pip-ephem-wheel-cache-127jqzvs\wheels\62\be\3a\90782c795f0ba93fec4a55c551ac7e8f7e7ea933797e4f71c0
# Successfully built tensortrade
# Installing collected packages: tensortrade
#   Found existing installation: tensortrade 0.0.2rc0
#     Uninstalling tensortrade-0.0.2rc0:
#       Successfully uninstalled tensortrade-0.0.2rc0
# Successfully installed tensortrade-0.0.2rc0

# %%
import os
import sys
import warnings
import numpy
import ccxt
import pandas as pd
import numpy as np
from time import time
import math
import cProfile as cp
import matplotlib.pyplot as plt

from gym.spaces import Space, Box

config = './neat.config'

def warn(*args, **kwargs):
    pass

warnings.warn = warn
warnings.simplefilter(action='ignore', category=FutureWarning)
numpy.seterr(divide = 'ignore') 

sys.path.append(os.path.dirname(os.path.abspath('')))
sys.path.append(os.path.abspath('')+"\\tensortrade")

# %% [markdown]
# **Load Data**

# %%
data_file ='./data/processed/binance/btc_usdt_1h.csv' 
df = pd.read_csv(data_file, index_col=[0])


# number of days we want to pull from the dataframe 
days_of_data = 365

# number of data frames (our DF is in 1h timesteps)
frames = days_of_data * 24 * 5
# frames = len(df)
train_test_percentage = 0.4

x_train = int(frames * (1 - train_test_percentage))
x_test = int(frames - x_train)

df_train = df[-frames:(-x_test - 1)]
df_test = df[-x_test:]
print("Friend Shape", df.shape)
print('train shape', df_train.shape)
print('test shape', df_test.shape)
print('columns', df.columns)
# Out:
# Friend Shape (180236, 12)
# train shape (26279, 12)
# test shape (17520, 12)
# columns Index(['open', 'high', 'low', 'close', 'volume', 'momentum_rsi', 'adx',
#        'adx_long', 'adx_pos', 'adx_neg', 'trend_ema_fast', 'trend_ema_slow'],
#       dtype='object')

# %% [markdown]
# **Train against training data**

# %%
import tensortrade
from neat_trading_strategy import NeatTradingStrategy as TradingStrategy
from neat_reward_strategy import NeatRewardStrategy as ProfitStrategy
from tensortrade.actions import DiscreteActionStrategy as ActionStrategy
from tensortrade.exchanges.simulated import SimulatedExchange as Exchange
from tensortrade.features.scalers import MinMaxNormalizer
from tensortrade.features import FeaturePipeline
from tensortrade.environments import TradingEnvironment as Environment

print('fin imports')
normalize = MinMaxNormalizer(inplace=True)
feature_pipeline = FeaturePipeline(steps=[normalize])

reward_strategy = ProfitStrategy()
action_strategy = ActionStrategy(n_actions=20, instrument_symbol='BTC/USDT')
print('fin strats')

exchange = Exchange(data_frame=df_train,
                    pretransform = True,
                    base_instrument='USDT', 
                    commission_percent=0.75,
                    window_size=1,
                    max_allowed_slippage_percent=3.0,
                    min_order_amount=1E-4,
                    min_trade_amount=1E-4,
                    observation_columns = df_train.columns
                   )
print('fin exchange')

environment = Environment(exchange=exchange,
                                 action_strategy=action_strategy,
                                 reward_strategy=reward_strategy,
                                 feature_pipeline=feature_pipeline)
print('fin environment')
print('')
strategy = TradingStrategy(environment=environment, 
                           neat_config=config, 
                           watch_genome_evaluation=True,
                           only_show_profitable=False,
                           learn_to_trade_theshold=-10000,
                           data_frame_window = 288
                          )

print("Running through ", strategy._data_frame_window, ' steps')
# cp.run("performance, winner, stats = strategy.run(generations=20)", 'evolution_stats')
performance, winner, stats = strategy.run(generations=200)
# Out:
# Population's average fitness: 12.98786 stdev: 302.64800
# Best fitness: 1000.00000 - size: (14, 165) - species 11 - id 71
# Average adjusted fitness: 0.354
# Mean genetic distance 3.673, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    10     51.9    0.293     5
#      2    7    10    -23.0    0.286     6
#      3    7    10   -100.0    0.281     7
#      4    7    10    283.0    0.309     4
#      5    7    10    978.0    0.354     6
#      6    7    10    607.9    0.327     0
#      7    7    10   1000.0    0.365     6
#      8    7    10    -23.0    0.303     6
#      9    7    10    -89.0    0.283     6
#     10    7    10    -89.0    0.281     6
#     11    7    10   1000.0    0.365     6
#     12    7    10    676.7    0.425     0
#     13    7    10    989.0    0.365     6
#     14    7    10   1000.0    0.352     6
#     15    7    10    -67.0    0.302     7
#     16    7    10    989.0    0.352     6
#     17    7    10    989.0    0.494     7
#     18    7    10    937.1    0.412     3
#     19    7    10   1000.0    0.443     6
#     20    7    10   1000.0    0.499     6
# Total extinctions: 0
# Generation time: 32.997 sec (29.401 average)
#
#  ****** Running generation 8 ******
#
# ---------------------------
# Genome ID:  3
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  30
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  31
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  32
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  33
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  34
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  35
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  36
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  37
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  38
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  59
# Rewards: -89
# Balance: 2603.7299999999996
# Net Worth: 9905.878723157999
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 1})
# ---------------------------
# Genome ID:  10
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  57
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  58
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  60
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  61
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  62
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  63
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_SELL: 3>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  64
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  65
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  9
# Rewards: 331.3824303870025
# Balance: 778.3099999999995
# Net Worth: 9986.665610213398
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1})
# ---------------------------
# Genome ID:  123
# Rewards: -89
# Balance: 2542.1400000000003
# Net Worth: 9852.725485845
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 1})
# ---------------------------
# Genome ID:  125
# Rewards: -311.25991708798983
# Balance: 1425.9500000000007
# Net Worth: 9949.256292353302
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1})
# ---------------------------
# Genome ID:  120
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  121
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  122
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  124
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  126
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  127
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  128
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  15
# Rewards: -67
# Balance: 0.05000000000035909
# Net Worth: 10084.2042779216
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  156
# Rewards: -67
# Balance: 0.279999999999923
# Net Worth: 10130.4221282243
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  157
# Rewards: -67
# Balance: 0.049999999999847944
# Net Worth: 10152.554883994899
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  158
# Rewards: -67
# Balance: 0.06999999999979067
# Net Worth: 10441.39820783
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  159
# Rewards: -67
# Balance: 0.08000000000009244
# Net Worth: 9881.3197242259
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 2, <TradeType.LIMIT_BUY: 1>: 1})
# ---------------------------
# Genome ID:  160
# Rewards: -67
# Balance: 0.14999999999926716
# Net Worth: 10045.996383923999
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  161
# Rewards: -78
# Balance: 0.23999999999919908
# Net Worth: 10167.6519351336
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 2})
# ---------------------------
# Genome ID:  162
# Rewards: -67
# Balance: 0.23000000000062748
# Net Worth: 9952.039560800002
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  163
# Rewards: -67
# Balance: 0.019999999999841922
# Net Worth: 10078.8996179232
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  164
# Rewards: -67
# Balance: 0.32000000000073037
# Net Worth: 10214.573334472301
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  29
# Rewards: -23
# Balance: 0.8100000000004255
# Net Worth: 9915.843907948003
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 7})
# ---------------------------
# Genome ID:  2
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  21
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  22
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  23
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  24
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  25
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  26
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  27
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  28
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  139
# Rewards: -23
# Balance: 0.8700000000000765
# Net Worth: 9622.276802377999
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 7})
# ---------------------------
# Genome ID:  141
# Rewards: -56
# Balance: 0.050000000000022915
# Net Worth: 10037.9547941606
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.LIMIT_BUY: 1>, 2), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 2, <TradeType.MARKET_BUY: 2>: 2})
# ---------------------------
# Genome ID:  8
# Rewards: -106.30632068025794
# Balance: 9904.710000000001
# Net Worth: 9905.161268213802
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_BUY: 2>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter({<TradeType.MARKET_SELL: 4>: 7, <TradeType.MARKET_BUY: 2>: 1})
# ---------------------------
# Genome ID:  142
# Rewards: -67
# Balance: 0.039999999999342895
# Net Worth: 9931.7883300088
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  143
# Rewards: -67
# Balance: 0.07999999999927931
# Net Worth: 8929.4617592
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  145
# Rewards: -67
# Balance: 0.2999999999992493
# Net Worth: 9488.1557991588
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  138
# Rewards: -67
# Balance: 0.08000000000062713
# Net Worth: 10304.066342045999
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  144
# Rewards: -78
# Balance: 0.7200000000006526
# Net Worth: 9867.9126468478
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 2})
# ---------------------------
# Genome ID:  146
# Rewards: -67
# Balance: 0.029999999999706928
# Net Worth: 9777.0419508864
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  140
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 2)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  102
# Rewards: -89
# Balance: 3138.4300000000003
# Net Worth: 9942.159763016502
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1})
# ---------------------------
# Genome ID:  109
# Rewards: -59.91653766274978
# Balance: 10114.850000000002
# Net Worth: 10114.850000000002
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.MARKET_SELL: 4>, 1), (<TradeType.MARKET_BUY: 2>, 1), (<TradeType.LIMIT_SELL: 3>, 1)])
# Number of trades: Counter({<TradeType.MARKET_SELL: 4>: 2, <TradeType.LIMIT_BUY: 1>: 1, <TradeType.MARKET_BUY: 2>: 1})
# ---------------------------
# Genome ID:  1
# Rewards: -91.08176810948915
# Balance: 9995.46
# Net Worth: 9995.46
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1, <TradeType.LIMIT_SELL: 3>: 1})
# ---------------------------
# Genome ID:  105
# Rewards: -84.66723089920393
# Balance: 10005.74
# Net Worth: 10005.74
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.LIMIT_SELL: 3>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1, <TradeType.LIMIT_SELL: 3>: 1})
# ---------------------------
# Genome ID:  103
# Rewards: -74.50320778817424
# Balance: 10179.91
# Net Worth: 10179.91
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 1, <TradeType.LIMIT_SELL: 3>: 1})
# ---------------------------
# Genome ID:  104
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  106
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_SELL: 4>, 2)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  107
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  108
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  110
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  117
# Rewards: -584.3566122256806
# Balance: 1052.7000000000007
# Net Worth: 9867.1972030425
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1})
# ---------------------------
# Genome ID:  118
# Rewards: -67
# Balance: 0.08999999999977071
# Net Worth: 9931.010230413
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  4
# Rewards: -367.99535857359655
# Balance: 2524.34
# Net Worth: 9931.700439758799
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1})
# ---------------------------
# Genome ID:  119
# Rewards: -112.18138482271026
# Balance: 1472.7999999999993
# Net Worth: 9970.2646188238
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1})
# ---------------------------
# Genome ID:  114
# Rewards: -89
# Balance: 3627.7200000000003
# Net Worth: 9916.999896608
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1})
# ---------------------------
# Genome ID:  111
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  112
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  113
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  115
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  116
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  51
# Rewards: 485.0011900477134
# Balance: 12074.239999999996
# Net Worth: 12074.239999999996
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 39, <TradeType.MARKET_SELL: 4>: 39})
# ---------------------------
# Genome ID:  6
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  48
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  49
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 2), (<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  50
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  52
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  53
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  54
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  55
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  56
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  180
# Rewards: 435.8396580423156
# Balance: 125.86000000000058
# Net Worth: 10440.0706213966
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 1})
# ---------------------------
# Genome ID:  177
# Rewards: 624.4863565937438
# Balance: 409.34000000000015
# Net Worth: 10373.7544779326
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 1})
# ---------------------------
# Genome ID:  175
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  181
# Rewards: -89
# Balance: 2650.1000000000004
# Net Worth: 9958.185745540399
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1})
# ---------------------------
# Genome ID:  182
# Rewards: -46.03332801932736
# Balance: 10390.5
# Net Worth: 10390.5
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.LIMIT_BUY: 1>, 2), (<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.HOLD: 0>, 2), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 2, <TradeType.MARKET_BUY: 2>: 1, <TradeType.LIMIT_SELL: 3>: 1, <TradeType.MARKET_SELL: 4>: 1})
# ---------------------------
# Genome ID:  176
# Rewards: -85.04909881104723
# Balance: 8252.43
# Net Worth: 9991.2712441086
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.MARKET_SELL: 4>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1, <TradeType.MARKET_SELL: 4>: 1})
# ---------------------------
# Genome ID:  174
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.HOLD: 0>, 2), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  178
# Rewards: 587.8201062888569
# Balance: 231.0599999999995
# Net Worth: 10234.925027535299
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 1})
# ---------------------------
# Genome ID:  179
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 2), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  12
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  94
# Rewards: 940.4692769727303
# Balance: 99.58000000000096
# Net Worth: 9895.126176569196
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 2), (<TradeType.LIMIT_BUY: 1>, 2), (<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 94, <TradeType.LIMIT_SELL: 3>: 1, <TradeType.MARKET_SELL: 4>: 1})
# ---------------------------
# Genome ID:  96
# Rewards: 622.8112103072756
# Balance: 292.6299999999992
# Net Worth: 10173.733009357598
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 1})
# ---------------------------
# Genome ID:  95
# Rewards: 124.2411616007403
# Balance: 2194.300000000001
# Net Worth: 9265.064766410003
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.MARKET_BUY: 2>, 1), (<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 18, <TradeType.LIMIT_SELL: 3>: 13, <TradeType.MARKET_SELL: 4>: 9, <TradeType.LIMIT_BUY: 1>: 3})
# ---------------------------
# Genome ID:  93
# Rewards: -47.32679950371692
# Balance: 0.1599999999994175
# Net Worth: 10084.27991707
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 2), (<TradeType.LIMIT_BUY: 1>, 2), (<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 3, <TradeType.MARKET_BUY: 2>: 2, <TradeType.LIMIT_SELL: 3>: 1})
# ---------------------------
# Genome ID:  98
# Rewards: -56
# Balance: 0.040000000000527614
# Net Worth: 10262.610457476998
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_BUY: 2>, 2)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 4})
# ---------------------------
# Genome ID:  101
# Rewards: -67
# Balance: 0.070000000000217
# Net Worth: 10133.870642523998
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  97
# Rewards: -89
# Balance: 2756.71
# Net Worth: 10148.681944318
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_BUY: 2>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 1})
# ---------------------------
# Genome ID:  18
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  99
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  100
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  47
# Rewards: 65
# Balance: 0.3299999999993465
# Net Worth: 9691.141672569198
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.LIMIT_BUY: 1>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 15})
# ---------------------------
# Genome ID:  45
# Rewards: -67
# Balance: 0.08000000000021856
# Net Worth: 9914.75714468
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_BUY: 2>, 1)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 3})
# ---------------------------
# Genome ID:  41
# Rewards: -84.02575787151713
# Balance: 10009.43
# Net Worth: 10009.43
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.MARKET_SELL: 4>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1, <TradeType.MARKET_SELL: 4>: 1})
# ---------------------------
# Genome ID:  44
# Rewards: -98.1844375355301
# Balance: 9904.400000000001
# Net Worth: 9904.400000000001
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_BUY: 1>, 1), (<TradeType.MARKET_SELL: 4>, 1), (<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 1, <TradeType.MARKET_SELL: 4>: 1})
# ---------------------------
# Genome ID:  5
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 2), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  39
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 2), (<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  40
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  42
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1), (<TradeType.LIMIT_SELL: 3>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  43
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 2), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  46
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 2), (<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  92
# Rewards: 989
# Balance: 139.1799999999998
# Net Worth: 9608.163757684399
# Steps Completed 100
# Most common action dict_items([(<TradeType.LIMIT_SELL: 3>, 1), (<TradeType.MARKET_BUY: 2>, 1), (<TradeType.LIMIT_BUY: 1>, 1)])
# Number of trades: Counter({<TradeType.LIMIT_BUY: 1>: 98, <TradeType.MARKET_BUY: 2>: 1})
# ---------------------------
# Genome ID:  16
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  84
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  85
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  86
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  87
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.MARKET_SELL: 4>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  88
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  89
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  90
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# Genome ID:  91
# Rewards: -100
# Balance: 10000.0
# Net Worth: 10000.0
# Steps Completed 100
# Most common action dict_items([(<TradeType.HOLD: 0>, 1)])
# Number of trades: Counter()
# ---------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b1db3f8e58ee> in <module>
#      44 print("Running through ", strategy._data_frame_window, ' steps')
#      45 # cp.run("performance, winner, stats = strategy.run(generations=20)", 'evolution_stats')
# ---> 46 performance, winner, stats = strategy.run(generations=200)
#
# ~\Dev\trader\tensortrade\neat_trading_strategy.py in run(self, generations, testing, episode_callback)
#     326         # pe = neat.ParallelEvaluator(10, self._threaded_eval)
#     327         # winner = self._pop.run(pe.evaluate, generations)
# --> 328         winner = self._pop.run(self._eval_population, generations)
#     329
#     330         # Display the winning genome.
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\neat\population.py in run(self, fitness_function, n)
#      87
#      88             # Evaluate all genomes using the user-provided function.
# ---> 89             fitness_function(list(iteritems(self.population)), self.config)
#      90
#      91             # Gather and report statistics.
#
# ~\Dev\trader\tensortrade\neat_trading_strategy.py in _eval_population(self, genomes, config)
#     249             self.environment._current_step = self._data_frame_start_tick
#     250
# --> 251             genome.fitness = self.eval_genome(genome, config)
#     252
#     253         clear_output()
#
# ~\Dev\trader\tensortrade\neat_trading_strategy.py in eval_genome(self, genome, config)
#     289
#     290             # feed action into environment to get reward for selected action
# --> 291             obs, rewards, done, info = self.environment.step(action)
#     292
#     293             # feed rewards to NEAT to calculate fitness.
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py in step(self, action)
#     186             info (dict): Any auxiliary, diagnostic, or debugging information to output.
#     187         """
# --> 188         executed_trade, filled_trade = self._take_action(action)
#     189         observation = self._next_observation()
#     190         reward = self._get_reward(filled_trade)
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\environments\trading_environment.py in _take_action(self, action)
#     121         """
#     122         executed_trade = self._action_strategy.get_trade(action=action)
# --> 123         filled_trade = self._exchange.execute_trade(executed_trade)
#     124
#     125         return executed_trade, filled_trade
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\exchanges\simulated\simulated_exchange.py in execute_trade(self, trade)
#     260
#     261             # print('Valid',self.balance, trade.to_dict)
# --> 262             self._update_account(trade)
#     263         else:
#     264             trade.valid = False
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\tensortrade\exchanges\simulated\simulated_exchange.py in _update_account(self, trade)
#     196                                                 'type': trade.trade_type,
#     197                                                 'amount': trade.transact_amount,
# --> 198                                                 'price': trade.transact_total}, ignore_index=True)
#     199
#     200         self._portfolio[self._base_instrument] = self._balance
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7096                 columns=combined_columns,
#    7097             )
# -> 7098             other = other._convert(datetime=True, timedelta=True)
#    7099             if not self.columns.equals(combined_columns):
#    7100                 self = self.reindex(columns=combined_columns)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in _convert(self, datetime, numeric, timedelta, coerce, copy)
#    6045                 timedelta=timedelta,
#    6046                 coerce=coerce,
# -> 6047                 copy=copy,
#    6048             )
#    6049         ).__finalize__(self)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\managers.py in convert(self, **kwargs)
#     582
#     583     def convert(self, **kwargs):
# --> 584         return self.apply("convert", **kwargs)
#     585
#     586     def replace(self, value, **kwargs):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     442             return self.make_empty(axes or self.axes)
#     443         bm = self.__class__(
# --> 444             result_blocks, axes or self.axes, do_integrity_check=do_integrity_check
#     445         )
#     446         bm._consolidate_inplace()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     145         self._consolidate_check()
#     146
# --> 147         self._rebuild_blknos_and_blklocs()
#     148
#     149     def make_empty(self, axes=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     226             rl = blk.mgr_locs
#     227             new_blknos[rl.indexer] = blkno
# --> 228             new_blklocs[rl.indexer] = np.arange(len(rl))
#     229
#     230         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %% [markdown]
# **Evaluate against full dataset**

# %%
exchange = Exchange(data_frame=df,
                    should_pretransform_obs = True,
                    base_instrument='USDT', 
                    timeframe='1h',
                    dtype=np.float32,
                    commission_percent=0.5,
                    window_size=1,
                    max_allowed_slippage_percent=3.0,
                    min_order_amount=1E-4,
                    min_trade_amount=1E-4
                   )
environment = Environment(exchange=exchange,
                                 action_strategy=action_strategy,
                                 reward_strategy=reward_strategy,
                                 feature_pipeline=feature_pipeline)

environment.reset()
from neat_trading_strategy import NeatTradingStrategy as TradingStrategy

strategy = TradingStrategy(environment=environment, watch_genome_evaluation=True, full_evaluation = True, neat_config=config)

# %%
strategy.eval_genome(winner)

# %%
print(environment.exchange.trades)
environment.exchange.performance.net_worth.plot()

# %%
import visualize

visualize.plot_stats(stats, ylog=False, view=True)

# %%
visualize.plot_species(stats, view=True)

# %%
visualize.draw_net(strategy._config, winner, False, node_names=node_names)

# %% [markdown]
# **Save Strategy**

# %%
columns = ["Action"]+list(exchange.data_frame.columns)

nodes = list(range(len(columns)*-1,1))
nodes.reverse()
node_names = dict( zip(nodes, columns))
print(node_names)

# %%
dir(winner.connections.keys)
keys = list(winner.connections.values())

keys[0].weight/5

# %%
from tensortrade.trades import Trade, TradeType
tt = TradeType(3)
t = Trade("btc/usdt",tt, 1, 100)
t.price
t.transact_price
t.fset('transact_price') = 123
