# %%
# %matplotlib inline
# %load_ext autoreload

# %autoreload 2
import tensorflow as tf
tf.enable_eager_execution()
tf.executing_eagerly()
# Out:
# True

# %%
# !pip install ../forks/tensortrade_source/ -U
# Out:
# Processing c:\users\codeninja\dev\forks\tensortrade_source
# Requirement already satisfied, skipping upgrade: numpy==1.16.4 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade==0.1.0rc1) (1.16.4)
# Requirement already satisfied, skipping upgrade: pandas==0.25.0 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade==0.1.0rc1) (0.25.0)
# Requirement already satisfied, skipping upgrade: gym==0.14.0 in c:\users\codeninja\appdata\roaming\python\python37\site-packages (from tensortrade==0.1.0rc1) (0.14.0)
# Requirement already satisfied, skipping upgrade: pyyaml==5.1.2 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from tensortrade==0.1.0rc1) (5.1.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pandas==0.25.0->tensortrade==0.1.0rc1) (2.8.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pandas==0.25.0->tensortrade==0.1.0rc1) (2019.3)
# Requirement already satisfied, skipping upgrade: cloudpickle~=1.2.0 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.1.0rc1) (1.2.2)
# Requirement already satisfied, skipping upgrade: six in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.1.0rc1) (1.12.0)
# Requirement already satisfied, skipping upgrade: pyglet<=1.3.2,>=1.2.0 in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.1.0rc1) (1.3.2)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from gym==0.14.0->tensortrade==0.1.0rc1) (1.3.1)
# Requirement already satisfied, skipping upgrade: future in c:\users\codeninja\anaconda3\envs\tt_fresh\lib\site-packages (from pyglet<=1.3.2,>=1.2.0->gym==0.14.0->tensortrade==0.1.0rc1) (0.18.1)
# Building wheels for collected packages: tensortrade
#   Building wheel for tensortrade (setup.py): started
#   Building wheel for tensortrade (setup.py): finished with status 'done'
#   Created wheel for tensortrade: filename=tensortrade-0.1.0rc1-cp37-none-any.whl size=73702 sha256=25404971a906f6ee98126c820e5c28f60c8c9b1644a8018a34eceada8bcc6c64
#   Stored in directory: C:\Users\CODENI~1\AppData\Local\Temp\pip-ephem-wheel-cache-a50msfq4\wheels\62\be\3a\90782c795f0ba93fec4a55c551ac7e8f7e7ea933797e4f71c0
# Successfully built tensortrade
# Installing collected packages: tensortrade
#   Found existing installation: tensortrade 0.1.0rc1
#     Uninstalling tensortrade-0.1.0rc1:
#       Successfully uninstalled tensortrade-0.1.0rc1
# Successfully installed tensortrade-0.1.0rc1

# %%
import os
import sys
import warnings
import numpy
import ccxt
import pandas as pd
import numpy as np
from time import time
import math
import cProfile as cp
import matplotlib.pyplot as plt

from gym.spaces import Space, Box

config = './neat.config'

def warn(*args, **kwargs):
    pass

warnings.warn = warn
warnings.simplefilter(action='ignore', category=FutureWarning)
numpy.seterr(divide = 'ignore') 

sys.path.append(os.path.dirname(os.path.abspath('')))
sys.path.append(os.path.abspath('')+"\\tensortrade")

# %% [markdown]
# **Load Data**

# %%
data_file ='./data/processed/binance/btc_usdt_1h.csv' 
df = pd.read_csv(data_file, index_col=[0])


# number of days we want to pull from the dataframe 
days_of_data = 365

# number of data frames (our DF is in 1h timesteps)
frames = days_of_data * 24 * 5
# frames = len(df)
train_test_percentage = 0.4

x_train = int(frames * (1 - train_test_percentage))
x_test = int(frames - x_train)

df_train = df[-frames:(-x_test - 1)]
df_test = df[-x_test:]
print("Friend Shape", df.shape)
print('train shape', df_train.shape)
print('test shape', df_test.shape)
print('columns', df.columns)
# Out:
# Friend Shape (180236, 12)
# train shape (26279, 12)
# test shape (17520, 12)
# columns Index(['open', 'high', 'low', 'close', 'volume', 'momentum_rsi', 'adx',
#        'adx_long', 'adx_pos', 'adx_neg', 'trend_ema_fast', 'trend_ema_slow'],
#       dtype='object')

# %%
df_test.head()
# Out:
#                          open      high       low     close      volume  \
# index
# 2019-08-28 03:35:00  10148.20  10155.65  10140.00  10140.49  103.707956
# 2019-08-28 03:40:00  10140.74  10148.78  10125.01  10133.83  73.728054
# 2019-08-28 03:45:00  10135.11  10145.87  10120.00  10120.01  102.866752
# 2019-08-28 03:50:00  10120.02  10133.51  10116.34  10120.03  55.034065
# 2019-08-28 03:55:00  10120.03  10130.00  10119.02  10126.17  48.912488
#
#                      momentum_rsi        adx  adx_long    adx_pos    adx_neg  \
# index
# 2019-08-28 03:35:00  34.890237     19.680116  9.632237  15.942283  24.099556
# 2019-08-28 03:40:00  30.560787     19.729527  9.551850  14.434463  27.784685
# 2019-08-28 03:45:00  23.560759     20.578936  9.524416  12.994025  26.944578
# 2019-08-28 03:50:00  23.589984     21.604012  9.514225  12.128909  26.569855
# 2019-08-28 03:55:00  32.704088     22.726318  9.516439  11.597170  25.405014
#
#                      trend_ema_fast  trend_ema_slow
# index
# 2019-08-28 03:35:00  10153.780045    10155.268113
# 2019-08-28 03:40:00  10150.710807    10153.680105
# 2019-08-28 03:45:00  10145.987606    10151.186023
# 2019-08-28 03:50:00  10141.994128    10148.878170
# 2019-08-28 03:55:00  10139.559647    10147.196083

# %% [markdown]
# **Train against training data**

# %%
import tensortrade
from neat_trading_strategy import NeatTradingStrategy as TradingStrategy
from neat_reward_strategy import NeatRewardStrategy as ProfitStrategy
from tensortrade.actions import DiscreteActions
from tensortrade.exchanges.simulated import SimulatedExchange as Exchange
from tensortrade.features.scalers import MinMaxNormalizer
from tensortrade.features import FeaturePipeline
from tensortrade.environments import TradingEnvironment as Environment

print('fin imports')
normalize = MinMaxNormalizer(inplace=True)
feature_pipeline = FeaturePipeline(steps=[normalize])

reward_scheme = ProfitStrategy()
action_scheme = DiscreteActions(n_actions=5, instrument='BTC/USDT')
print('fin strats')

exchange = Exchange(data_frame=df_train,
                    pretransform = True,
                    base_instrument='USDT', 
                    commission_percent=0.75,
                    window_size=1,
                    max_allowed_slippage_percent=3.0,
                    min_order_amount=1E-4,
                    min_trade_amount=1E-4,
                    observation_columns = df_train.columns
                   )
print('fin exchange')

environment = Environment(exchange=exchange,
                                 action_scheme=action_scheme,
                                 reward_scheme=reward_scheme,
                                 feature_pipeline=feature_pipeline)
print('fin environment')
print('')

segments_in_day = 288
days = 7

strategy = TradingStrategy(environment=environment, 
                           neat_config=config, 
                           watch_genome_evaluation=False,
                           only_show_profitable=False,
                           learn_to_trade_theshold=-10000,
                           data_frame_window = segments_in_day * days
                          )

print("Running through ", strategy._data_frame_window, ' steps')
# cp.run("performance, winner, stats = strategy.run(generations=20)", 'evolution_stats')
performance, winner, stats = strategy.run(generations=200)
# Out:
# fin imports
# fin strats
# fin exchange
# fin environment
#
# Running through  2016  steps
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 1.80954 stdev: 2.55681
# Best fitness: 11.19080 - size: (13, 169) - species 5 - id 5
# Average adjusted fitness: 0.162
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    10      3.0    0.268     0
#      2    0    10      0.0    0.000     0
#      3    0    10      2.0    0.179     0
#      4    0    10      0.0    0.000     0
#      5    0    10     11.2    1.000     0
#      6    0    10      3.0    0.268     0
#      7    0    10      3.0    0.268     0
#      8    0    10      0.0    0.000     0
#      9    0    10      0.0    0.000     0
#     10    0    10      3.0    0.268     0
#     11    0    10      3.0    0.268     0
#     12    0    10      0.0    0.000     0
#     13    0    10      0.0    0.000     0
#     14    0    10      2.0    0.179     0
#     15    0    10      0.0    0.000     0
#     16    0    10      0.0    0.000     0
#     17    0    10      3.0    0.268     0
#     18    0    10      0.0    0.000     0
#     19    0    10      0.0    0.000     0
#     20    0    10      3.0    0.268     0
# Total extinctions: 0
# Generation time: 35.877 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 52.56673 stdev: 701.31058
# Best fitness: 9945.63987 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    10      3.0    0.000     1
#      2    1    10      3.0    0.000     0
#      3    1    10      3.0    0.000     0
#      4    1    10      3.0    0.000     0
#      5    1    10   9945.6    0.101     0
#      6    1    10     16.2    0.001     0
#      7    1    10      3.0    0.000     1
#      8    1    10      3.0    0.000     0
#      9    1    10      3.0    0.000     0
#     10    1    10      3.0    0.000     1
#     11    1    10      3.0    0.000     1
#     12    1    10     11.2    0.000     0
#     13    1    10     11.2    0.000     0
#     14    1    10      3.0    0.000     0
#     15    1    10     11.2    0.001     0
#     16    1    10     12.2    0.001     0
#     17    1    10      3.0    0.000     1
#     18    1    10     11.2    0.000     0
#     19    1    10      3.0    0.000     0
#     20    1    10      3.0    0.000     1
# Total extinctions: 0
# Generation time: 278.570 sec (157.224 average)
# Saving checkpoint to neat-checkpoint-1
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 53.41411 stdev: 712.82245
# Best fitness: 10108.88428 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    10      3.0    0.000     2
#      2    2    10      3.0    0.000     1
#      3    2    10      3.0    0.000     1
#      4    2    10      3.0    0.000     1
#      5    2    10  10108.9    0.101     0
#      6    2    10     15.2    0.001     1
#      7    2    10      3.0    0.000     2
#      8    2    10      3.0    0.000     1
#      9    2    10      3.0    0.000     1
#     10    2    10      3.0    0.000     2
#     11    2    10      3.0    0.000     2
#     12    2    10     11.2    0.000     1
#     13    2    10     11.2    0.000     1
#     14    2    10      3.0    0.000     1
#     15    2    10     11.2    0.000     1
#     16    2    10     12.2    0.001     0
#     17    2    10      3.0    0.000     2
#     18    2    10     11.2    0.000     1
#     19    2    10      3.0    0.000     1
#     20    2    10      3.0    0.000     2
# Total extinctions: 0
# Generation time: 277.157 sec (197.201 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 51.16101 stdev: 682.05278
# Best fitness: 9672.57635 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    10      3.0    0.000     3
#      2    3    10      3.0    0.000     2
#      3    3    10      3.0    0.000     2
#      4    3    10      3.0    0.000     2
#      5    3    10   9672.6    0.100     1
#      6    3    10     13.2    0.001     2
#      7    3    10      3.0    0.000     3
#      8    3    10      3.0    0.000     2
#      9    3    10      3.0    0.000     2
#     10    3    10      3.0    0.000     3
#     11    3    10      3.0    0.000     3
#     12    3    10     11.2    0.000     2
#     13    3    10     11.2    0.000     2
#     14    3    10      3.0    0.000     2
#     15    3    10     11.2    0.001     2
#     16    3    10     11.2    0.001     1
#     17    3    10      3.0    0.000     3
#     18    3    10     11.2    0.000     2
#     19    3    10      3.0    0.000     2
#     20    3    10      3.0    0.000     3
# Total extinctions: 0
# Generation time: 284.125 sec (218.932 average)
# Saving checkpoint to neat-checkpoint-3
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 52.22493 stdev: 698.57502
# Best fitness: 9906.71784 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    10      3.0    0.000     4
#      2    4    10      3.0    0.000     3
#      3    4    10      3.0    0.000     3
#      4    4    10      3.0    0.000     3
#      5    4    10   9906.7    0.100     2
#      6    4    10     16.2    0.001     3
#      7    4    10      3.0    0.000     4
#      8    4    10      3.0    0.000     3
#      9    4    10      3.0    0.000     3
#     10    4    10      3.0    0.000     4
#     11    4    10      3.0    0.000     4
#     12    4    10     11.2    0.000     3
#     13    4    10      0.0    0.000     3
#     14    4    10      3.0    0.000     3
#     15    4    10     11.2    0.001     3
#     16    4    10     12.2    0.001     2
#     17    4    10      3.0    0.000     4
#     18    4    10     11.2    0.000     3
#     19    4    10      3.0    0.000     3
#     20    4    10      3.0    0.000     4
# Total extinctions: 0
# Generation time: 280.825 sec (231.311 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 53.78083 stdev: 719.52487
# Best fitness: 10203.81144 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    10      3.0    0.000     5
#      2    5    10      3.0    0.000     4
#      3    5    10      3.0    0.000     4
#      4    5    10      3.0    0.000     4
#      5    5    10  10203.8    0.100     0
#      6    5    10     15.2    0.001     4
#      7    5    10      3.0    0.000     5
#      8    5    10      3.0    0.000     4
#      9    5    10      3.0    0.000     4
#     10    5    10      3.0    0.000     5
#     11    5    10      3.0    0.000     5
#     12    5    10     11.2    0.000     4
#     13    5    10     11.2    0.000     4
#     14    5    10      3.0    0.000     4
#     15    5    10     11.2    0.000     4
#     16    5    10     12.2    0.001     0
#     17    5    10      3.0    0.000     5
#     18    5    10     11.2    0.000     4
#     19    5    10      3.0    0.000     4
#     20    5    10      3.0    0.000     5
# Total extinctions: 0
# Generation time: 282.027 sec (239.764 average)
# Saving checkpoint to neat-checkpoint-5
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 54.63812 stdev: 735.64321
# Best fitness: 10432.06201 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    10      3.0    0.000     6
#      2    6    10      3.0    0.000     5
#      3    6    10      3.0    0.000     5
#      4    6    10      3.0    0.000     5
#      5    6    10  10432.1    0.100     0
#      6    6    10     13.2    0.001     5
#      7    6    10      3.0    0.000     6
#      8    6    10      3.0    0.000     5
#      9    6    10      2.0    0.000     5
#     10    6    10      3.0    0.000     6
#     11    6    10      3.0    0.000     6
#     12    6    10     11.2    0.000     5
#     13    6    10     11.2    0.000     5
#     14    6    10      3.0    0.000     5
#     15    6    10     11.2    0.000     5
#     16    6    10     12.2    0.000     1
#     17    6    10      3.0    0.000     6
#     18    6    10      0.0    0.000     5
#     19    6    10      3.0    0.000     5
#     20    6    10      3.0    0.000     6
# Total extinctions: 0
# Generation time: 267.830 sec (243.773 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 54.35226 stdev: 726.63756
# Best fitness: 10304.71070 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    10      3.0    0.000     7
#      2    7    10      3.0    0.000     6
#      3    7    10      3.0    0.000     6
#      4    7    10      3.0    0.000     6
#      5    7    10  10304.7    0.100     1
#      6    7    10     16.2    0.001     6
#      7    7    10      3.0    0.000     7
#      8    7    10      3.0    0.000     6
#      9    7    10      2.0    0.000     6
#     10    7    10      3.0    0.000     7
#     11    7    10      3.0    0.000     7
#     12    7    10     11.2    0.000     6
#     13    7    10     11.2    0.000     6
#     14    7    10      3.0    0.000     6
#     15    7    10     11.2    0.000     6
#     16    7    10     12.2    0.001     2
#     17    7    10      3.0    0.000     7
#     18    7    10      0.0    0.000     6
#     19    7    10      3.0    0.000     6
#     20    7    10      3.0    0.000     7
# Total extinctions: 0
# Generation time: 264.220 sec (246.329 average)
# Saving checkpoint to neat-checkpoint-7
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 50.24451 stdev: 669.91187
# Best fitness: 9500.38456 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    10      3.0    0.000     8
#      2    8    10      3.0    0.000     7
#      3    8    10      3.0    0.000     7
#      4    8    10      3.0    0.000     7
#      5    8    10   9500.4    0.100     2
#      6    8    10     16.2    0.001     7
#      7    8    10      3.0    0.000     8
#      8    8    10      3.0    0.000     7
#      9    8    10      3.0    0.000     7
#     10    8    10      3.0    0.000     8
#     11    8    10      3.0    0.000     8
#     12    8    10     11.2    0.000     7
#     13    8    10     11.2    0.000     7
#     14    8    10      3.0    0.000     7
#     15    8    10     11.2    0.001     7
#     16    8    10     11.2    0.001     3
#     17    8    10      3.0    0.000     8
#     18    8    10     11.2    0.000     7
#     19    8    10      3.0    0.000     7
#     20    8    10      3.0    0.000     8
# Total extinctions: 0
# Generation time: 250.292 sec (246.769 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 53.54226 stdev: 715.07654
# Best fitness: 10140.81532 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    10      3.0    0.000     9
#      2    9    10      3.0    0.000     8
#      3    9    10      3.0    0.000     8
#      4    9    10      3.0    0.000     8
#      5    9    10  10140.8    0.100     3
#      6    9    10     16.2    0.001     8
#      7    9    10      3.0    0.000     9
#      8    9    10      3.0    0.000     8
#      9    9    10      3.0    0.000     8
#     10    9    10      3.0    0.000     9
#     11    9    10      3.0    0.000     9
#     12    9    10     11.2    0.000     8
#     13    9    10     11.2    0.000     8
#     14    9    10      3.0    0.000     8
#     15    9    10     11.2    0.000     8
#     16    9    10     11.2    0.001     4
#     17    9    10      3.0    0.000     9
#     18    9    10     11.2    0.000     8
#     19    9    10      3.0    0.000     8
#     20    9    10      3.0    0.000     9
# Total extinctions: 0
# Generation time: 249.161 sec (247.008 average)
# Saving checkpoint to neat-checkpoint-9
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 52.93106 stdev: 704.42771
# Best fitness: 9989.97198 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    10      3.0    0.000    10
#      2   10    10      3.0    0.000     9
#      3   10    10      3.0    0.000     9
#      4   10    10      3.0    0.000     9
#      5   10    10   9990.0    0.100     4
#      6   10    10     16.2    0.001     0
#      7   10    10      3.0    0.000    10
#      8   10    10      3.0    0.000     9
#      9   10    10      3.0    0.000     9
#     10   10    10      3.0    0.000    10
#     11   10    10      3.0    0.000    10
#     12   10    10     11.2    0.000     9
#     13   10    10     11.2    0.000     9
#     14   10    10      3.0    0.000     9
#     15   10    10     11.2    0.001     9
#     16   10    10     12.2    0.001     5
#     17   10    10      3.0    0.000    10
#     18   10    10     11.2    0.000     9
#     19   10    10      3.0    0.000     9
#     20   10    10      3.0    0.000    10
# Total extinctions: 0
# Generation time: 249.968 sec (268.418 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 52.80361 stdev: 704.14561
# Best fitness: 9985.87189 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    10      3.0    0.000    11
#      2   11    10      3.0    0.000    10
#      3   11    10      3.0    0.000    10
#      4   11    10      3.0    0.000    10
#      5   11    10   9985.9    0.101     5
#      6   11    10     16.2    0.001     0
#      7   11    10      3.0    0.000    11
#      8   11    10      3.0    0.000    10
#      9   11    10      3.0    0.000    10
#     10   11    10      3.0    0.000    11
#     11   11    10      3.0    0.000    11
#     12   11    10     11.2    0.000    10
#     13   11    10     11.2    0.000    10
#     14   11    10      3.0    0.000    10
#     15   11    10     11.2    0.001    10
#     16   11    10     11.2    0.000     6
#     17   11    10      3.0    0.000    11
#     18   11    10     11.2    0.000    10
#     19   11    10      3.0    0.000    10
#     20   11    10      3.0    0.000    11
# Total extinctions: 0
# Generation time: 250.714 sec (265.632 average)
# Saving checkpoint to neat-checkpoint-11
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 54.49709 stdev: 727.82137
# Best fitness: 10321.55445 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    10      3.0    0.000    12
#      2   12    10      3.0    0.000    11
#      3   12    10      3.0    0.000    11
#      4   12    10      3.0    0.000    11
#      5   12    10  10321.6    0.100     6
#      6   12    10     16.2    0.001     1
#      7   12    10      3.0    0.000    12
#      8   12    10      3.0    0.000    11
#      9   12    10      3.0    0.000    11
#     10   12    10      3.0    0.000    12
#     11   12    10      3.0    0.000    12
#     12   12    10     11.2    0.000    11
#     13   12    10     11.2    0.000    11
#     14   12    10      3.0    0.000    11
#     15   12    10     11.2    0.000    11
#     16   12    10     11.2    0.001     7
#     17   12    10      3.0    0.000    12
#     18   12    10     11.2    0.000    11
#     19   12    10      3.0    0.000    11
#     20   12    10      3.0    0.000    12
# Total extinctions: 0
# Generation time: 251.051 sec (263.021 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 55.68024 stdev: 743.43219
# Best fitness: 10542.95448 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    10      3.0    0.000    13
#      2   13    10      3.0    0.000    12
#      3   13    10      3.0    0.000    12
#      4   13    10      3.0    0.000    12
#      5   13    10  10543.0    0.100     0
#      6   13    10     16.2    0.001     2
#      7   13    10      3.0    0.000    13
#      8   13    10      3.0    0.000    12
#      9   13    10      3.0    0.000    12
#     10   13    10      3.0    0.000    13
#     11   13    10      3.0    0.000    13
#     12   13    10     11.2    0.000    12
#     13   13    10     11.2    0.000    12
#     14   13    10      3.0    0.000    12
#     15   13    10     11.2    0.001    12
#     16   13    10     12.2    0.001     8
#     17   13    10      3.0    0.000    13
#     18   13    10     11.2    0.000    12
#     19   13    10      3.0    0.000    12
#     20   13    10      3.0    0.000    13
# Total extinctions: 0
# Generation time: 252.297 sec (259.839 average)
# Saving checkpoint to neat-checkpoint-13
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 51.36245 stdev: 686.91947
# Best fitness: 9741.43982 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    10      3.0    0.000    14
#      2   14    10      3.0    0.000    13
#      3   14    10      3.0    0.000    13
#      4   14    10      3.0    0.000    13
#      5   14    10   9741.4    0.100     1
#      6   14    10     15.2    0.001     3
#      7   14    10      3.0    0.000    14
#      8   14    10      3.0    0.000    13
#      9   14    10      2.0    0.000    13
#     10   14    10      3.0    0.000    14
#     11   14    10      3.0    0.000    14
#     12   14    10     11.2    0.000    13
#     13   14    10     11.2    0.000    13
#     14   14    10      3.0    0.000    13
#     15   14    10     11.2    0.000    13
#     16   14    10     11.2    0.001     9
#     17   14    10      3.0    0.000    14
#     18   14    10     11.2    0.000    13
#     19   14    10      3.0    0.000    13
#     20   14    10      3.0    0.000    14
# Total extinctions: 0
# Generation time: 249.902 sec (256.746 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 54.35586 stdev: 721.93362
# Best fitness: 10238.34030 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    10      3.0    0.000    15
#      2   15    10      3.0    0.000    14
#      3   15    10      3.0    0.000    14
#      4   15    10      3.0    0.000    14
#      5   15    10  10238.3    0.101     2
#      6   15    10     16.2    0.001     4
#      7   15    10      3.0    0.000    15
#      8   15    10      3.0    0.000    14
#      9   15    10      3.0    0.000    14
#     10   15    10      3.0    0.000    15
#     11   15    10      3.0    0.000    15
#     12   15    10     11.2    0.000    14
#     13   15    10     11.2    0.000    14
#     14   15    10      3.0    0.000    14
#     15   15    10     11.2    0.001    14
#     16   15    10     12.2    0.001    10
#     17   15    10      3.0    0.000    15
#     18   15    10     11.2    0.000    14
#     19   15    10      3.0    0.000    14
#     20   15    10      3.0    0.000    15
# Total extinctions: 0
# Generation time: 250.460 sec (253.589 average)
# Saving checkpoint to neat-checkpoint-15
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 52.35755 stdev: 697.19594
# Best fitness: 9887.38165 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    10      3.0    0.000    16
#      2   16    10      3.0    0.000    15
#      3   16    10      3.0    0.000    15
#      4   16    10      3.0    0.000    15
#      5   16    10   9887.4    0.100     3
#      6   16    10     15.2    0.001     5
#      7   16    10      3.0    0.000    16
#      8   16    10      3.0    0.000    15
#      9   16    10      3.0    0.000    15
#     10   16    10      3.0    0.000    16
#     11   16    10      3.0    0.000    16
#     12   16    10     11.2    0.000    15
#     13   16    10     11.2    0.000    15
#     14   16    10      3.0    0.000    15
#     15   16    10     11.2    0.000    15
#     16   16    10     12.2    0.001    11
#     17   16    10      3.0    0.000    16
#     18   16    10     11.2    0.000    15
#     19   16    10      3.0    0.000    15
#     20   16    10      3.0    0.000    16
# Total extinctions: 0
# Generation time: 250.632 sec (251.870 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 56.67560 stdev: 756.67024
# Best fitness: 10730.69477 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    10      3.0    0.000    17
#      2   17    10      3.0    0.000    16
#      3   17    10      3.0    0.000    16
#      4   17    10      3.0    0.000    16
#      5   17    10  10730.7    0.101     0
#      6   17    10     15.2    0.001     6
#      7   17    10      3.0    0.000    17
#      8   17    10      3.0    0.000    16
#      9   17    10      3.0    0.000    16
#     10   17    10      3.0    0.000    17
#     11   17    10      3.0    0.000    17
#     12   17    10     11.2    0.000    16
#     13   17    10     11.2    0.000    16
#     14   17    10      3.0    0.000    16
#     15   17    10     11.2    0.000    16
#     16   17    10     11.2    0.001    12
#     17   17    10      3.0    0.000    17
#     18   17    10     11.2    0.000    16
#     19   17    10      3.0    0.000    16
#     20   17    10      3.0    0.000    17
# Total extinctions: 0
# Generation time: 251.317 sec (250.580 average)
# Saving checkpoint to neat-checkpoint-17
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 55.22284 stdev: 738.41405
# Best fitness: 10471.71162 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    10      3.0    0.000    18
#      2   18    10      3.0    0.000    17
#      3   18    10      3.0    0.000    17
#      4   18    10      3.0    0.000    17
#      5   18    10  10471.7    0.101     1
#      6   18    10     15.2    0.001     7
#      7   18    10      3.0    0.000    18
#      8   18    10      3.0    0.000    17
#      9   18    10      3.0    0.000    17
#     10   18    10      3.0    0.000    18
#     11   18    10      3.0    0.000    18
#     12   18    10     11.2    0.000    17
#     13   18    10     11.2    0.000    17
#     14   18    10      3.0    0.000    17
#     15   18    10     11.2    0.000    17
#     16   18    10     12.2    0.001    13
#     17   18    10      3.0    0.000    18
#     18   18    10     11.2    0.000    17
#     19   18    10      3.0    0.000    17
#     20   18    10      3.0    0.000    18
# Total extinctions: 0
# Generation time: 251.945 sec (250.745 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 2296.84254 stdev: 32359.33703
# Best fitness: 458781.46354 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.005
# Mean genetic distance 3.678, standard deviation 0.748
# Population of 200 members in 20 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    10      3.0    0.000    19
#      2   19    10      3.0    0.000    18
#      3   19    10      3.0    0.000    18
#      4   19    10      3.0    0.000    18
#      5   19    10  458781.5    0.100     0
#      6   19    10     16.2    0.000     8
#      7   19    10      3.0    0.000    19
#      8   19    10      3.0    0.000    18
#      9   19    10      3.0    0.000    18
#     10   19    10      3.0    0.000    19
#     11   19    10      3.0    0.000    19
#     12   19    10     11.2    0.000    18
#     13   19    10     11.2    0.000    18
#     14   19    10      3.0    0.000    18
#     15   19    10     11.2    0.000    18
#     16   19    10     12.2    0.000    14
#     17   19    10      3.0    0.000    19
#     18   19    10     11.2    0.000    18
#     19   19    10      3.0    0.000    18
#     20   19    10      3.0    0.000    19
# Total extinctions: 0
# Generation time: 3208.446 sec (546.673 average)
# Saving checkpoint to neat-checkpoint-19
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 53.39100 stdev: 715.02145
# Best fitness: 10139.89134 - size: (14, 169) - species 5 - id 192
#
# Species 1 with 10 members is stagnated: removing it
#
# Species 7 with 10 members is stagnated: removing it
#
# Species 10 with 10 members is stagnated: removing it
#
# Species 11 with 10 members is stagnated: removing it
#
# Species 17 with 10 members is stagnated: removing it
#
# Species 20 with 10 members is stagnated: removing it
# Average adjusted fitness: 0.007
# Mean genetic distance 3.604, standard deviation 0.882
# Population of 140 members in 14 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   20    10      3.0    0.000    19
#      3   20    10      3.0    0.000    19
#      4   20    10      3.0    0.000    19
#      5   20    10  10139.9    0.100     1
#      6   20    10     16.2    0.001     9
#      8   20    10      3.0    0.000    19
#      9   20    10      3.0    0.000    19
#     12   20    10     11.2    0.000    19
#     13   20    10     11.2    0.000    19
#     14   20    10      3.0    0.000    19
#     15   20    10     11.2    0.000    19
#     16   20    10     11.2    0.001    15
#     18   20    10     11.2    0.000    19
#     19   20    10      3.0    0.000    19
# Total extinctions: 0
# Generation time: 250.604 sec (546.737 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 77.10274 stdev: 872.03489
# Best fitness: 10358.11020 - size: (14, 169) - species 5 - id 192
#
# Species 9 with 10 members is stagnated: removing it
#
# Species 2 with 10 members is stagnated: removing it
#
# Species 4 with 10 members is stagnated: removing it
#
# Species 8 with 10 members is stagnated: removing it
#
# Species 19 with 10 members is stagnated: removing it
#
# Species 3 with 10 members is stagnated: removing it
#
# Species 14 with 10 members is stagnated: removing it
#
# Species 18 with 10 members is stagnated: removing it
#
# Species 13 with 10 members is stagnated: removing it
#
# Species 12 with 10 members is stagnated: removing it
#
# Species 15 with 10 members is stagnated: removing it
# Average adjusted fitness: 0.034
# Mean genetic distance 2.699, standard deviation 1.619
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   21    10  10358.1    0.100     2
#      6   21    10     16.2    0.001    10
#     16   21    10     11.2    0.001    16
# Total extinctions: 0
# Generation time: 175.934 sec (539.259 average)
# Saving checkpoint to neat-checkpoint-21
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 362.85221 stdev: 1917.07869
# Best fitness: 10686.59599 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.034
# Mean genetic distance 2.699, standard deviation 1.619
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   22    10  10686.6    0.100     3
#      6   22    10     16.2    0.001    11
#     16   22    10     12.2    0.001     0
# Total extinctions: 0
# Generation time: 44.460 sec (518.600 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 340.57409 stdev: 1790.68021
# Best fitness: 9983.64353 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.034
# Mean genetic distance 2.699, standard deviation 1.619
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   23    10   9983.6    0.101     4
#      6   23    10     15.2    0.001    12
#     16   23    10     12.2    0.001     1
# Total extinctions: 0
# Generation time: 43.072 sec (497.677 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 343.95026 stdev: 1820.60152
# Best fitness: 10148.15051 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.034
# Mean genetic distance 2.699, standard deviation 1.619
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   24    10  10148.2    0.101     5
#      6   24    10     16.2    0.001    13
#     16   24    10     11.2    0.001     2
# Total extinctions: 0
# Generation time: 43.421 sec (477.029 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 350.75207 stdev: 1848.90463
# Best fitness: 10307.36684 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.034
# Mean genetic distance 2.699, standard deviation 1.619
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   25    10  10307.4    0.100     6
#      6   25    10     16.2    0.001    14
#     16   25    10     11.2    0.001     3
# Total extinctions: 0
# Generation time: 43.682 sec (456.351 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 356.59729 stdev: 1880.95103
# Best fitness: 10485.79196 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.034
# Mean genetic distance 2.699, standard deviation 1.619
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   26    10  10485.8    0.101     7
#      6   26    10     14.2    0.001    15
#     16   26    10     11.2    0.001     4
# Total extinctions: 0
# Generation time: 43.567 sec (435.645 average)
# Saving checkpoint to neat-checkpoint-26
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 334.58246 stdev: 1763.90853
# Best fitness: 9833.47671 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.034
# Mean genetic distance 2.699, standard deviation 1.619
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   27    10   9833.5    0.100     8
#      6   27    10     16.2    0.001    16
#     16   27    10     12.2    0.001     5
# Total extinctions: 0
# Generation time: 42.464 sec (414.759 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 345.47201 stdev: 1823.85236
# Best fitness: 10167.17627 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.034
# Mean genetic distance 2.699, standard deviation 1.619
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   28    10  10167.2    0.100     9
#      6   28    10     14.2    0.001    17
#     16   28    10     11.2    0.001     6
# Total extinctions: 0
# Generation time: 42.365 sec (393.801 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 331.45416 stdev: 1743.27292
# Best fitness: 9719.22685 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.034
# Mean genetic distance 2.699, standard deviation 1.619
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   29    10   9719.2    0.101    10
#      6   29    10     16.2    0.001    18
#     16   29    10     12.2    0.001     7
# Total extinctions: 0
# Generation time: 42.539 sec (77.211 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 342.17954 stdev: 1802.55479
# Best fitness: 10049.19665 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.034
# Mean genetic distance 2.699, standard deviation 1.619
# Population of 30 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   30    10  10049.2    0.101    11
#      6   30    10     16.2    0.001    19
#     16   30    10     11.2    0.001     8
# Total extinctions: 0
# Generation time: 42.436 sec (56.394 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 331.88067 stdev: 1753.70871
# Best fitness: 9775.84421 - size: (14, 169) - species 5 - id 192
#
# Species 6 with 10 members is stagnated: removing it
# Average adjusted fitness: 0.050
# Mean genetic distance 2.118, standard deviation 1.691
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   31    12   9775.8    0.100    12
#     16   31    10     12.2    0.000     9
# Total extinctions: 0
# Generation time: 42.054 sec (43.006 average)
# Saving checkpoint to neat-checkpoint-31
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 478.68071 stdev: 2161.88981
# Best fitness: 10385.67806 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.042
# Mean genetic distance 2.112, standard deviation 1.697
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   32    12  10385.7    0.084    13
#     16   32    10     12.2    0.001    10
# Total extinctions: 0
# Generation time: 31.067 sec (41.667 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 478.15813 stdev: 2163.72651
# Best fitness: 10393.57275 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.042
# Mean genetic distance 2.122, standard deviation 1.684
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   33    12  10393.6    0.084    14
#     16   33    10     11.2    0.001    11
# Total extinctions: 0
# Generation time: 31.017 sec (40.461 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 937.64810 stdev: 2945.71756
# Best fitness: 10404.42326 - size: (14, 169) - species 5 - id 206
# Average adjusted fitness: 0.083
# Mean genetic distance 2.124, standard deviation 1.682
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   34    12  10404.4    0.165    15
#     16   34    10     12.2    0.001    12
# Total extinctions: 0
# Generation time: 37.894 sec (39.908 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 912.60276 stdev: 2866.19962
# Best fitness: 10181.76967 - size: (14, 169) - species 5 - id 206
# Average adjusted fitness: 0.082
# Mean genetic distance 2.130, standard deviation 1.674
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   35    12  10181.8    0.164    16
#     16   35    10     12.2    0.001    13
# Total extinctions: 0
# Generation time: 30.997 sec (38.640 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 1328.52522 stdev: 3328.49974
# Best fitness: 10041.94118 - size: (15, 167) - species 5 - id 209
# Average adjusted fitness: 0.121
# Mean genetic distance 2.132, standard deviation 1.667
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   36    12  10041.9    0.242    17
#     16   36    10     11.2    0.001    14
# Total extinctions: 0
# Generation time: 37.744 sec (38.058 average)
# Saving checkpoint to neat-checkpoint-36
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 2409.27820 stdev: 4431.42522
# Best fitness: 10902.89313 - size: (15, 167) - species 5 - id 209
# Average adjusted fitness: 0.203
# Mean genetic distance 2.146, standard deviation 1.649
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   37    12  10902.9    0.405    18
#     16   37    10     11.2    0.001    15
# Total extinctions: 0
# Generation time: 38.398 sec (37.651 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 2324.81006 stdev: 4272.75232
# Best fitness: 10553.57321 - size: (15, 171) - species 5 - id 212
# Average adjusted fitness: 0.202
# Mean genetic distance 2.158, standard deviation 1.628
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   38    12  10553.6    0.403    19
#     16   38    10     12.2    0.001    16
# Total extinctions: 0
# Generation time: 33.690 sec (36.783 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 104993.13619 stdev: 193607.32757
# Best fitness: 471844.23961 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.204
# Mean genetic distance 2.156, standard deviation 1.629
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   39    12  471844.2    0.408     0
#     16   39    10     11.2    0.000    17
# Total extinctions: 0
# Generation time: 461.022 sec (78.632 average)
# Saving checkpoint to neat-checkpoint-39
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 2312.29605 stdev: 4250.62243
# Best fitness: 10404.60313 - size: (14, 169) - species 5 - id 206
# Average adjusted fitness: 0.204
# Mean genetic distance 2.163, standard deviation 1.622
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   40    12  10404.6    0.407     1
#     16   40    10     11.2    0.001    18
# Total extinctions: 0
# Generation time: 33.454 sec (77.733 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 2815.88685 stdev: 4588.77148
# Best fitness: 11066.70075 - size: (14, 169) - species 5 - id 192
# Average adjusted fitness: 0.233
# Mean genetic distance 2.162, standard deviation 1.626
# Population of 22 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   41    12  11066.7    0.466     2
#     16   41    10     11.2    0.001    19
# Total extinctions: 0
# Generation time: 40.652 sec (77.593 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 2744.69310 stdev: 4473.10522
# Best fitness: 10399.43752 - size: (15, 170) - species 5 - id 219
#
# Species 16 with 10 members is stagnated: removing it
# Average adjusted fitness: 0.483
# Mean genetic distance 0.794, standard deviation 0.163
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   42    20  10399.4    0.483     3
# Total extinctions: 0
# Generation time: 34.690 sec (77.956 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 4503.30464 stdev: 4975.77737
# Best fitness: 10607.06515 - size: (16, 172) - species 5 - id 232
# Average adjusted fitness: 0.425
# Mean genetic distance 0.909, standard deviation 0.199
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   43    20  10607.1    0.425     4
# Total extinctions: 0
# Generation time: 41.515 sec (79.005 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 6115.49963 stdev: 4994.35679
# Best fitness: 10757.47283 - size: (16, 169) - species 5 - id 225
# Average adjusted fitness: 0.568
# Mean genetic distance 0.882, standard deviation 0.191
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   44    20  10757.5    0.568     5
# Total extinctions: 0
# Generation time: 43.722 sec (79.588 average)
# Saving checkpoint to neat-checkpoint-44
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 7080.14582 stdev: 4638.37366
# Best fitness: 10532.07632 - size: (17, 173) - species 5 - id 236
# Average adjusted fitness: 0.672
# Mean genetic distance 0.830, standard deviation 0.185
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   45    20  10532.1    0.672     6
# Total extinctions: 0
# Generation time: 44.366 sec (80.925 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 6133.91696 stdev: 5012.16378
# Best fitness: 10642.66560 - size: (15, 170) - species 5 - id 240
# Average adjusted fitness: 0.576
# Mean genetic distance 0.860, standard deviation 0.194
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   46    20  10642.7    0.576     7
# Total extinctions: 0
# Generation time: 44.119 sec (81.563 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 6169.45547 stdev: 5041.11390
# Best fitness: 10842.60969 - size: (17, 173) - species 5 - id 236
# Average adjusted fitness: 0.569
# Mean genetic distance 0.922, standard deviation 0.217
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   47    20  10842.6    0.569     8
# Total extinctions: 0
# Generation time: 44.519 sec (82.175 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 8235.10464 stdev: 4125.81752
# Best fitness: 11095.21335 - size: (16, 172) - species 5 - id 232
# Average adjusted fitness: 0.742
# Mean genetic distance 0.930, standard deviation 0.206
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   48    20  11095.2    0.742     9
# Total extinctions: 0
# Generation time: 45.546 sec (83.360 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 6585.24631 stdev: 4837.36531
# Best fitness: 10859.05070 - size: (17, 172) - species 5 - id 281
# Average adjusted fitness: 0.606
# Mean genetic distance 0.965, standard deviation 0.221
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   49    20  10859.1    0.606    10
# Total extinctions: 0
# Generation time: 44.326 sec (41.691 average)
# Saving checkpoint to neat-checkpoint-49
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 6080.46408 stdev: 4965.04127
# Best fitness: 10495.47811 - size: (17, 173) - species 5 - id 236
# Average adjusted fitness: 0.579
# Mean genetic distance 0.954, standard deviation 0.216
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   50    20  10495.5    0.579    11
# Total extinctions: 0
# Generation time: 45.017 sec (42.847 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 6651.41865 stdev: 4883.27508
# Best fitness: 10800.36634 - size: (17, 173) - species 5 - id 236
# Average adjusted fitness: 0.616
# Mean genetic distance 0.927, standard deviation 0.154
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   51    20  10800.4    0.616    12
# Total extinctions: 0
# Generation time: 44.700 sec (43.252 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 7175.93065 stdev: 4698.99090
# Best fitness: 10818.03490 - size: (16, 168) - species 5 - id 313
# Average adjusted fitness: 0.663
# Mean genetic distance 0.787, standard deviation 0.206
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   52    20  10818.0    0.663    13
# Total extinctions: 0
# Generation time: 44.634 sec (44.246 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 5650.11899 stdev: 5111.63865
# Best fitness: 10649.94784 - size: (18, 173) - species 5 - id 311
# Average adjusted fitness: 0.531
# Mean genetic distance 0.821, standard deviation 0.173
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   53    20  10649.9    0.531    14
# Total extinctions: 0
# Generation time: 44.071 sec (44.502 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 7564.94275 stdev: 4379.81194
# Best fitness: 11125.14583 - size: (18, 170) - species 5 - id 337
# Average adjusted fitness: 0.680
# Mean genetic distance 0.867, standard deviation 0.181
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   54    20  11125.1    0.680    15
# Total extinctions: 0
# Generation time: 45.064 sec (44.636 average)
# Saving checkpoint to neat-checkpoint-54
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 7756.07205 stdev: 4478.60340
# Best fitness: 10888.74388 - size: (19, 173) - species 5 - id 333
# Average adjusted fitness: 0.712
# Mean genetic distance 0.993, standard deviation 0.216
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   55    20  10888.7    0.712    16
# Total extinctions: 0
# Generation time: 45.632 sec (44.763 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 7034.18446 stdev: 4610.11927
# Best fitness: 10448.68325 - size: (18, 170) - species 5 - id 348
# Average adjusted fitness: 0.673
# Mean genetic distance 0.964, standard deviation 0.208
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   56    20  10448.7    0.673    17
# Total extinctions: 0
# Generation time: 44.509 sec (44.802 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 7164.59304 stdev: 4694.27174
# Best fitness: 10805.23935 - size: (19, 168) - species 5 - id 356
# Average adjusted fitness: 0.663
# Mean genetic distance 0.999, standard deviation 0.210
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   57    20  10805.2    0.663    18
# Total extinctions: 0
# Generation time: 45.087 sec (44.859 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 7552.35004 stdev: 4363.47975
# Best fitness: 10473.48043 - size: (20, 173) - species 5 - id 369
# Average adjusted fitness: 0.721
# Mean genetic distance 1.004, standard deviation 0.239
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   58    20  10473.5    0.721    19
# Total extinctions: 0
# Generation time: 45.131 sec (44.817 average)
#
# ...
# 	DefaultConnectionGene(key=(-8, 51), weight=-0.20752127218240482, enabled=True)
# 	DefaultConnectionGene(key=(-8, 52), weight=-1.5362169441021494, enabled=False)
# 	DefaultConnectionGene(key=(-8, 53), weight=2.241800581029744, enabled=True)
# 	DefaultConnectionGene(key=(-8, 54), weight=0.009707280413628894, enabled=True)
# 	DefaultConnectionGene(key=(-8, 55), weight=-1.2341395831765214, enabled=False)
# 	DefaultConnectionGene(key=(-8, 56), weight=0.4112266448437312, enabled=False)
# 	DefaultConnectionGene(key=(-8, 57), weight=4.619588493638673, enabled=True)
# 	DefaultConnectionGene(key=(-8, 58), weight=-2.1653449793553268, enabled=True)
# 	DefaultConnectionGene(key=(-8, 59), weight=0.46520426075788834, enabled=True)
# 	DefaultConnectionGene(key=(-8, 60), weight=0.5082235467584835, enabled=True)
# 	DefaultConnectionGene(key=(-7, 50), weight=-0.8361316816204485, enabled=True)
# 	DefaultConnectionGene(key=(-7, 51), weight=1.1032950960029781, enabled=False)
# 	DefaultConnectionGene(key=(-7, 52), weight=-5.1582274192921815, enabled=True)
# 	DefaultConnectionGene(key=(-7, 53), weight=0.5980314990241208, enabled=True)
# 	DefaultConnectionGene(key=(-7, 54), weight=-1.8388412874540807, enabled=True)
# 	DefaultConnectionGene(key=(-7, 55), weight=-1.5526142287433784, enabled=True)
# 	DefaultConnectionGene(key=(-7, 56), weight=0.5999625977151092, enabled=True)
# 	DefaultConnectionGene(key=(-7, 57), weight=1.74917586256431, enabled=True)
# 	DefaultConnectionGene(key=(-7, 58), weight=1.155358779681736, enabled=True)
# 	DefaultConnectionGene(key=(-7, 59), weight=-1.693049058204676, enabled=False)
# 	DefaultConnectionGene(key=(-7, 60), weight=1.97472741980478, enabled=True)
# 	DefaultConnectionGene(key=(-7, 576), weight=-2.5759503663725862, enabled=False)
# 	DefaultConnectionGene(key=(-7, 1023), weight=-2.282354482559482, enabled=True)
# 	DefaultConnectionGene(key=(-7, 1705), weight=-0.6929828272233175, enabled=True)
# 	DefaultConnectionGene(key=(-6, 50), weight=0.7364256356782448, enabled=True)
# 	DefaultConnectionGene(key=(-6, 51), weight=3.774453214352615, enabled=True)
# 	DefaultConnectionGene(key=(-6, 52), weight=1.0057353047163895, enabled=False)
# 	DefaultConnectionGene(key=(-6, 53), weight=-1.0214102503633034, enabled=True)
# 	DefaultConnectionGene(key=(-6, 54), weight=1.1640537184864637, enabled=True)
# 	DefaultConnectionGene(key=(-6, 55), weight=-0.860113392309551, enabled=True)
# 	DefaultConnectionGene(key=(-6, 56), weight=1.5044667654715642, enabled=True)
# 	DefaultConnectionGene(key=(-6, 57), weight=0.8980740971836056, enabled=False)
# 	DefaultConnectionGene(key=(-6, 58), weight=-0.37231773714982963, enabled=False)
# 	DefaultConnectionGene(key=(-6, 59), weight=0.023730769720037403, enabled=True)
# 	DefaultConnectionGene(key=(-6, 60), weight=-0.38002885057984376, enabled=True)
# 	DefaultConnectionGene(key=(-6, 426), weight=0.043006658216186364, enabled=False)
# 	DefaultConnectionGene(key=(-6, 460), weight=-1.0042087760094285, enabled=True)
# 	DefaultConnectionGene(key=(-6, 1433), weight=1.7009478175277897, enabled=True)
# 	DefaultConnectionGene(key=(-6, 1590), weight=0.3460067988984222, enabled=True)
# 	DefaultConnectionGene(key=(-5, 50), weight=-0.43807628110055485, enabled=True)
# 	DefaultConnectionGene(key=(-5, 51), weight=1.1444928404471952, enabled=True)
# 	DefaultConnectionGene(key=(-5, 52), weight=1.046301188506377, enabled=True)
# 	DefaultConnectionGene(key=(-5, 53), weight=-3.528498771147012, enabled=True)
# 	DefaultConnectionGene(key=(-5, 54), weight=0.2515000597440114, enabled=True)
# 	DefaultConnectionGene(key=(-5, 55), weight=0.24507536291446438, enabled=False)
# 	DefaultConnectionGene(key=(-5, 56), weight=0.19505921345861665, enabled=False)
# 	DefaultConnectionGene(key=(-5, 57), weight=-3.9862442313549766, enabled=True)
# 	DefaultConnectionGene(key=(-5, 58), weight=-0.6525379343601853, enabled=True)
# 	DefaultConnectionGene(key=(-5, 59), weight=-2.4366511999655183, enabled=True)
# 	DefaultConnectionGene(key=(-5, 60), weight=-0.42964009076831816, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1120), weight=1.1099837600318587, enabled=False)
# 	DefaultConnectionGene(key=(-5, 1164), weight=0.23723792521242876, enabled=True)
# 	DefaultConnectionGene(key=(-4, 50), weight=-0.9793325407425388, enabled=True)
# 	DefaultConnectionGene(key=(-4, 51), weight=-5.315200379346498, enabled=True)
# 	DefaultConnectionGene(key=(-4, 52), weight=1.5148346106022896, enabled=True)
# 	DefaultConnectionGene(key=(-4, 53), weight=-1.0539281465646364, enabled=True)
# 	DefaultConnectionGene(key=(-4, 54), weight=-0.5130275177016718, enabled=True)
# 	DefaultConnectionGene(key=(-4, 55), weight=0.033614253747442646, enabled=True)
# 	DefaultConnectionGene(key=(-4, 56), weight=1.1059968008496024, enabled=False)
# 	DefaultConnectionGene(key=(-4, 57), weight=0.126306831090653, enabled=True)
# 	DefaultConnectionGene(key=(-4, 58), weight=-3.6987276953340666, enabled=True)
# 	DefaultConnectionGene(key=(-4, 59), weight=-0.41404793552592073, enabled=True)
# 	DefaultConnectionGene(key=(-4, 60), weight=-0.8292207377899389, enabled=True)
# 	DefaultConnectionGene(key=(-4, 509), weight=0.6465066636493457, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1062), weight=1.3932196001687394, enabled=False)
# 	DefaultConnectionGene(key=(-4, 1748), weight=-2.0438810593323296, enabled=True)
# 	DefaultConnectionGene(key=(-3, 50), weight=-0.8272860298867293, enabled=True)
# 	DefaultConnectionGene(key=(-3, 51), weight=0.6613702520861449, enabled=True)
# 	DefaultConnectionGene(key=(-3, 52), weight=1.1783141120799363, enabled=False)
# 	DefaultConnectionGene(key=(-3, 53), weight=1.7918072985339273, enabled=True)
# 	DefaultConnectionGene(key=(-3, 54), weight=2.755951846745957, enabled=True)
# 	DefaultConnectionGene(key=(-3, 55), weight=-0.4147620014782376, enabled=False)
# 	DefaultConnectionGene(key=(-3, 56), weight=-1.5010311720608045, enabled=True)
# 	DefaultConnectionGene(key=(-3, 57), weight=-3.0768932880788906, enabled=True)
# 	DefaultConnectionGene(key=(-3, 58), weight=1.209906147409861, enabled=False)
# 	DefaultConnectionGene(key=(-3, 59), weight=2.517523123414752, enabled=False)
# 	DefaultConnectionGene(key=(-3, 60), weight=-2.1228955131881446, enabled=True)
# 	DefaultConnectionGene(key=(-3, 485), weight=1.1624667020618107, enabled=False)
# 	DefaultConnectionGene(key=(-2, 50), weight=-0.11906792563107255, enabled=True)
# 	DefaultConnectionGene(key=(-2, 51), weight=0.787120149616768, enabled=False)
# 	DefaultConnectionGene(key=(-2, 52), weight=0.4656959105567061, enabled=True)
# 	DefaultConnectionGene(key=(-2, 53), weight=0.6567079041659721, enabled=False)
# 	DefaultConnectionGene(key=(-2, 55), weight=-1.5770366533305649, enabled=True)
# 	DefaultConnectionGene(key=(-2, 56), weight=2.8503491253358955, enabled=True)
# 	DefaultConnectionGene(key=(-2, 57), weight=-1.7187368562133285, enabled=True)
# 	DefaultConnectionGene(key=(-2, 58), weight=-0.0702847414151771, enabled=False)
# 	DefaultConnectionGene(key=(-2, 59), weight=2.392824367432721, enabled=True)
# 	DefaultConnectionGene(key=(-2, 60), weight=-1.633940876854917, enabled=False)
# 	DefaultConnectionGene(key=(-2, 808), weight=0.5772159581416522, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1062), weight=1.3658345007496653, enabled=False)
# 	DefaultConnectionGene(key=(-2, 1065), weight=-1.378574283285731, enabled=False)
# 	DefaultConnectionGene(key=(-2, 1505), weight=0.6282978986319516, enabled=True)
# 	DefaultConnectionGene(key=(-1, 50), weight=3.1263734819071876, enabled=False)
# 	DefaultConnectionGene(key=(-1, 51), weight=-1.234917643650247, enabled=False)
# 	DefaultConnectionGene(key=(-1, 52), weight=0.9682839694990573, enabled=False)
# 	DefaultConnectionGene(key=(-1, 53), weight=-1.9610042624763935, enabled=True)
# 	DefaultConnectionGene(key=(-1, 54), weight=-0.9891332774692936, enabled=True)
# 	DefaultConnectionGene(key=(-1, 55), weight=0.9437169884200718, enabled=True)
# 	DefaultConnectionGene(key=(-1, 56), weight=-2.08861070692668, enabled=True)
# 	DefaultConnectionGene(key=(-1, 57), weight=-1.331285598051201, enabled=True)
# 	DefaultConnectionGene(key=(-1, 58), weight=2.7328868362751617, enabled=True)
# 	DefaultConnectionGene(key=(-1, 59), weight=-1.388785445307064, enabled=False)
# 	DefaultConnectionGene(key=(-1, 60), weight=2.5647044350317802, enabled=False)
# 	DefaultConnectionGene(key=(0, 0), weight=-3.63441813255563, enabled=True)
# 	DefaultConnectionGene(key=(0, 509), weight=1.2592691263080802, enabled=True)
# 	DefaultConnectionGene(key=(0, 1264), weight=2.813085042402059, enabled=True)
# 	DefaultConnectionGene(key=(50, 0), weight=-0.07822086740559865, enabled=True)
# 	DefaultConnectionGene(key=(50, 50), weight=-2.7755657691806492, enabled=False)
# 	DefaultConnectionGene(key=(50, 53), weight=0.4953992385155267, enabled=True)
# 	DefaultConnectionGene(key=(51, 0), weight=-2.3822852216946058, enabled=True)
# 	DefaultConnectionGene(key=(51, 51), weight=0.45910153598880044, enabled=True)
# 	DefaultConnectionGene(key=(51, 593), weight=0.6729856527911038, enabled=True)
# 	DefaultConnectionGene(key=(52, 0), weight=0.39917063470576497, enabled=False)
# 	DefaultConnectionGene(key=(52, 52), weight=-0.4132208801506751, enabled=False)
# 	DefaultConnectionGene(key=(53, 0), weight=2.2382094685224496, enabled=False)
# 	DefaultConnectionGene(key=(53, 53), weight=-0.3016194425268893, enabled=True)
# 	DefaultConnectionGene(key=(53, 1239), weight=-0.4895069339450878, enabled=True)
# 	DefaultConnectionGene(key=(53, 1590), weight=-1.4092560020632086, enabled=True)
# 	DefaultConnectionGene(key=(53, 1721), weight=-0.4841334362837588, enabled=True)
# 	DefaultConnectionGene(key=(54, 0), weight=-0.5185118939018775, enabled=True)
# 	DefaultConnectionGene(key=(54, 54), weight=2.2644896414939066, enabled=True)
# 	DefaultConnectionGene(key=(55, 0), weight=-0.12746439626922912, enabled=True)
# 	DefaultConnectionGene(key=(55, 55), weight=-0.7134348884837305, enabled=True)
# 	DefaultConnectionGene(key=(56, 0), weight=4.309034806223743, enabled=True)
# 	DefaultConnectionGene(key=(56, 56), weight=0.03976691768772489, enabled=True)
# 	DefaultConnectionGene(key=(57, 0), weight=0.4910980321102437, enabled=True)
# 	DefaultConnectionGene(key=(57, 57), weight=0.4457824973327542, enabled=True)
# 	DefaultConnectionGene(key=(58, 0), weight=1.258597200695675, enabled=True)
# 	DefaultConnectionGene(key=(58, 52), weight=1.4058217802592217, enabled=True)
# 	DefaultConnectionGene(key=(58, 58), weight=-0.0026466002741800665, enabled=True)
# 	DefaultConnectionGene(key=(58, 1563), weight=4.647467188843602, enabled=True)
# 	DefaultConnectionGene(key=(59, 0), weight=2.0835688973244144, enabled=False)
# 	DefaultConnectionGene(key=(59, 59), weight=1.6479693281578482, enabled=True)
# 	DefaultConnectionGene(key=(59, 1754), weight=-0.8784600293596038, enabled=False)
# 	DefaultConnectionGene(key=(59, 1791), weight=1.3889821040017551, enabled=True)
# 	DefaultConnectionGene(key=(60, 0), weight=-2.984029634273771, enabled=True)
# 	DefaultConnectionGene(key=(60, 52), weight=-0.3987716735739109, enabled=True)
# 	DefaultConnectionGene(key=(60, 60), weight=-1.6459829431295385, enabled=True)
# 	DefaultConnectionGene(key=(426, 54), weight=-0.9809494032642083, enabled=True)
# 	DefaultConnectionGene(key=(426, 56), weight=-0.8784030898187389, enabled=True)
# 	DefaultConnectionGene(key=(460, 58), weight=0.774390829870882, enabled=True)
# 	DefaultConnectionGene(key=(485, 55), weight=-1.2146873591819556, enabled=True)
# 	DefaultConnectionGene(key=(509, 56), weight=-0.22882328656331213, enabled=False)
# 	DefaultConnectionGene(key=(509, 1529), weight=1.0874547376213775, enabled=True)
# 	DefaultConnectionGene(key=(509, 1754), weight=-0.5974315395986213, enabled=True)
# 	DefaultConnectionGene(key=(572, 0), weight=0.5805626818887203, enabled=True)
# 	DefaultConnectionGene(key=(572, 53), weight=-0.0937548450221054, enabled=True)
# 	DefaultConnectionGene(key=(576, 55), weight=1.2332837146670284, enabled=True)
# 	DefaultConnectionGene(key=(576, 60), weight=0.020215071150297845, enabled=True)
# 	DefaultConnectionGene(key=(593, 52), weight=0.6514454510804573, enabled=True)
# 	DefaultConnectionGene(key=(593, 58), weight=1.4126031412658542, enabled=True)
# 	DefaultConnectionGene(key=(593, 460), weight=2.737113946838082, enabled=True)
# 	DefaultConnectionGene(key=(808, 53), weight=0.10088572906052476, enabled=True)
# 	DefaultConnectionGene(key=(872, 52), weight=-0.17752033004169987, enabled=True)
# 	DefaultConnectionGene(key=(889, 0), weight=1.7400888390742157, enabled=False)
# 	DefaultConnectionGene(key=(889, 57), weight=0.5163497772501799, enabled=True)
# 	DefaultConnectionGene(key=(889, 889), weight=-3.547921228678705, enabled=False)
# 	DefaultConnectionGene(key=(971, 55), weight=-0.2646067702017305, enabled=False)
# 	DefaultConnectionGene(key=(971, 1239), weight=-0.15311312399997623, enabled=True)
# 	DefaultConnectionGene(key=(971, 1622), weight=-0.14344411784183142, enabled=True)
# 	DefaultConnectionGene(key=(1023, 52), weight=0.3235653896411249, enabled=True)
# 	DefaultConnectionGene(key=(1065, 52), weight=-1.3589462915290007, enabled=True)
# 	DefaultConnectionGene(key=(1065, 971), weight=-1.2564168061330192, enabled=True)
# 	DefaultConnectionGene(key=(1164, 55), weight=0.18160386194818123, enabled=True)
# 	DefaultConnectionGene(key=(1164, 58), weight=-0.3055434596575036, enabled=True)
# 	DefaultConnectionGene(key=(1188, 53), weight=-1.0946015039881924, enabled=True)
# 	DefaultConnectionGene(key=(1239, 55), weight=1.5251270967700308, enabled=True)
# 	DefaultConnectionGene(key=(1264, 509), weight=1.7115360971977311, enabled=True)
# 	DefaultConnectionGene(key=(1264, 1546), weight=3.1481227657018183, enabled=True)
# 	DefaultConnectionGene(key=(1279, 53), weight=-1.1330958885932296, enabled=True)
# 	DefaultConnectionGene(key=(1279, 872), weight=-1.1193839752895838, enabled=False)
# 	DefaultConnectionGene(key=(1279, 1286), weight=0.8312545526747086, enabled=True)
# 	DefaultConnectionGene(key=(1279, 1778), weight=0.549780189249006, enabled=True)
# 	DefaultConnectionGene(key=(1286, 53), weight=-0.9919615945885787, enabled=True)
# 	DefaultConnectionGene(key=(1286, 1264), weight=-0.38915355264598994, enabled=True)
# 	DefaultConnectionGene(key=(1372, 51), weight=-0.40135942094743565, enabled=True)
# 	DefaultConnectionGene(key=(1400, 58), weight=1.275239254358696, enabled=True)
# 	DefaultConnectionGene(key=(1433, 52), weight=-1.7842383593268272, enabled=True)
# 	DefaultConnectionGene(key=(1433, 60), weight=-1.176640808955379, enabled=True)
# 	DefaultConnectionGene(key=(1505, 60), weight=-2.934730292987687, enabled=True)
# 	DefaultConnectionGene(key=(1529, 56), weight=-1.8435577475285454, enabled=True)
# 	DefaultConnectionGene(key=(1546, 509), weight=0.708795936161779, enabled=True)
# 	DefaultConnectionGene(key=(1563, 52), weight=-0.9156664177241968, enabled=True)
# 	DefaultConnectionGene(key=(1563, 460), weight=-1.2021197987342482, enabled=True)
# 	DefaultConnectionGene(key=(1563, 1065), weight=-0.4169698185056205, enabled=True)
# 	DefaultConnectionGene(key=(1563, 1286), weight=1.0182281088463017, enabled=False)
# 	DefaultConnectionGene(key=(1563, 1889), weight=0.33794990398387664, enabled=True)
# 	DefaultConnectionGene(key=(1590, 57), weight=1.172297445180945, enabled=True)
# 	DefaultConnectionGene(key=(1622, 1239), weight=0.14090828298074454, enabled=True)
# 	DefaultConnectionGene(key=(1705, 51), weight=-3.3541081301037172, enabled=True)
# 	DefaultConnectionGene(key=(1721, 0), weight=0.3750779040611784, enabled=False)
# 	DefaultConnectionGene(key=(1723, 54), weight=-0.2536788832176193, enabled=True)
# 	DefaultConnectionGene(key=(1748, 52), weight=1.4196148454624635, enabled=True)
# 	DefaultConnectionGene(key=(1748, 1903), weight=-0.9424188561402868, enabled=True)
# 	DefaultConnectionGene(key=(1754, 0), weight=0.2585025164561976, enabled=True)
# 	DefaultConnectionGene(key=(1778, 872), weight=-2.794219573209567, enabled=True)
# 	DefaultConnectionGene(key=(1791, 1754), weight=0.6167379833544351, enabled=True)
# 	DefaultConnectionGene(key=(1824, 57), weight=-2.6598917583084356, enabled=True)
# 	DefaultConnectionGene(key=(1889, 1286), weight=-2.804050196915479, enabled=True)
# 	DefaultConnectionGene(key=(1903, 52), weight=-0.08853629081617942, enabled=True)
# 	DefaultConnectionGene(key=(1971, 55), weight=0.14420058404701458, enabled=True)

# %% [markdown]
# **Evaluate against full dataset**

# %%
exchange = Exchange(data_frame=df_test[-288*14:90-288*14],
                    pretransform = True,
                    base_instrument='USDT', 
                    commission_percent=0.075,
                    window_size=1,
                    max_allowed_slippage_percent=3.0,
                    min_order_amount=1E-4,
                    min_trade_amount=1E-4,
                    observation_columns = df_test.columns
                   )
environment = Environment(exchange=exchange,
                                 action_scheme=action_scheme,
                                 reward_scheme=reward_scheme,
                                 feature_pipeline=feature_pipeline)

environment.reset()
# from neat_trading_strategy import NeatTradingStrategy as TradingStrategy
# exchange.balance = 100000
strategy = strategy = TradingStrategy(environment=environment, 
                           neat_config=config, 
                           watch_genome_evaluation=True,
                           only_show_profitable=False,
                           full_evaluation=True
                          )
# TradingStrategy(environment=environment, watch_genome_evaluation=True, full_evaluation = True, neat_config=config)

# %%
environment.reset()
exchange.reset()
exchange._balance = 100
print("Starting Worth: {}".format(exchange.net_worth, exchange.balance))
print(exchange.trades)
strategy.eval_genome(winner, strategy._config)
# Out:
# Starting Worth: 100
# Empty DataFrame
# Columns: [step, symbol, type, amount, price]
# Index: []
# ---------------------------
# -------WE DONE!---------
# Genome ID:  1751
# Rewards: 246.0107829892936
# Balance: 155.07000000000005
# Net Worth: 155.07000000000005
# Steps Completed 89
# Most common action dict_items([('MARKET_SELL', 45), ('MARKET_BUY', 44)])
# Number of trades: Counter({<TradeType.MARKET_BUY: 2>: 36, <TradeType.MARKET_SELL: 4>: 36})
# 246.0107829892936

# %%
pd.set_option('display.max_colwidth', -1)

# %%
exchange.performance.tail()
# Out:
#     balance   net_worth  \
# 67  155.02   155.020000
# 68  5.14     157.059603
# 69  155.52   155.520000
# 70  4.72     157.129596
# 71  155.07   155.070000
#
#                                                                                                                                         action  \
# 67  299678fa-0b14-11ea-a7ee-d8cb8a39e9e7: TradeType.MARKET_SELL 0.01768415 units of BTC for 8391.88 each. Total:148.51 Comission:0.11@0.00075%
# 68  2999110c-0b14-11ea-b683-d8cb8a39e9e7: TradeType.MARKET_BUY 0.01831418 units of BTC for 8177.84 each. Total:149.88 Comission:0.11@0.00075
# 69  299a7098-0b14-11ea-be0d-d8cb8a39e9e7: TradeType.MARKET_SELL 0.01831418 units of BTC for 8204.98 each. Total:150.38 Comission:0.11@0.00075%
# 70  299bd01a-0b14-11ea-9bd5-d8cb8a39e9e7: TradeType.MARKET_BUY 0.0183891 units of BTC for 8194.43 each. Total:150.8 Comission:0.11@0.00075
# 71  299d2fbe-0b14-11ea-8ed5-d8cb8a39e9e7: TradeType.MARKET_SELL 0.0183891 units of BTC for 8170.16 each. Total:150.35 Comission:0.11@0.00075%
#
#    step
# 67  82
# 68  85
# 69  86
# 70  87
# 71  88

# %%
exchange.trades.tail()
# Out:
#    step symbol                   type    amount   price
# 67  82   BTC    TradeType.MARKET_SELL  0.017684  148.51
# 68  85   BTC    TradeType.MARKET_BUY   0.018314  149.88
# 69  86   BTC    TradeType.MARKET_SELL  0.018314  150.38
# 70  87   BTC    TradeType.MARKET_BUY   0.018389  150.80
# 71  88   BTC    TradeType.MARKET_SELL  0.018389  150.35

# %%
ax = plt.subplot(211)
exchange.performance.net_worth.plot(figsize=(22,16), label='net worth', title='Net Worth')
exchange.performance['com'] = exchange.trades.price*0.00075
ax2 = plt.subplot(212, sharex=ax)
exchange.performance.com.plot()
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-362-da8bf0aa4a06> in <module>
# ----> 1 ax = plt.subplot(211, size=16)
#       2 exchange.performance.net_worth.plot(figsize=(22,16), label='net worth', title='Net Worth')
#       3 exchange.performance['com'] = exchange.trades.price*0.00075
#       4 ax2 = plt.subplot(212, sharex=ax)
#       5 exchange.performance.com.plot()
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      67
#      68         # _axes_class is set in the subplot_class_factory
# ---> 69         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      70         # add a layout box to this, for both the full axis, and the poss
#      71         # of the axis.  We need both because the axes may become smaller
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     507             self.set_yscale(yscale)
#     508
# --> 509         self.update(kwargs)
#     510
#     511         if self.xaxis is not None:
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\matplotlib\artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~\Anaconda3\envs\tt_fresh\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'AxesSubplot' object has no property 'size'

# %%
exchange._performance.head()
# Out:
#    balance   net_worth  \
# 0  4.14     102.140002
# 1  102.70   102.700000
# 2  2.08     102.726000
# 3  104.49   104.490000
# 4  4.22     106.620188
#
#                                                                                                                                       action  \
# 0  175bee76-0aff-11ea-9947-d8cb8a39e9e7: TradeType.MARKET_BUY 0.01182942 units of BTC for 8097.66 each. Total:95.86 Comission:0.07@0.00075
# 1  175d4e14-0aff-11ea-b67c-d8cb8a39e9e7: TradeType.MARKET_SELL 0.01182942 units of BTC for 8325.6 each. Total:98.56 Comission:0.07@0.00075%
# 2  175efbba-0aff-11ea-81ae-d8cb8a39e9e7: TradeType.MARKET_BUY 0.01214943 units of BTC for 8275.44 each. Total:100.62 Comission:0.08@0.00075
# 3  17608258-0aff-11ea-a9cb-d8cb8a39e9e7: TradeType.MARKET_SELL 0.01214943 units of BTC for 8422.6 each. Total:102.41 Comission:0.08@0.00075%
# 4  176208fa-0aff-11ea-a3e6-d8cb8a39e9e7: TradeType.MARKET_BUY 0.01237309 units of BTC for 8097.44 each. Total:100.27 Comission:0.08@0.00075
#
#   step       com
# 0  1    0.071895
# 1  2    0.073920
# 2  3    0.075465
# 3  4    0.076808
# 4  5    0.075203

# %%
wins = 0
losses = 0 
ax = plt.subplot(211)

exchange._price_history.plot(figsize=(22,8), label='actual price')

# print(exchange._price_history.head())
# print(exchange.trades.head())
# print(exchange.performance.head())
for idx,trade in exchange.trades.iterrows():
    price_at_trade = exchange._price_history[trade.step-1]
    if trade.type.is_buy:
        plt.plot(trade.step-1 , price_at_trade, "b^")
    elif trade.type.is_sell:
        the_buy_step = exchange.trades.iloc[idx-1]
        profit = trade.price - the_buy_step.price
        if profit < 0:
            losses +=1
            color = '#d62728'
            plt.axvspan(the_buy_step.step-1, trade.step-1, alpha= 0.1, facecolor='red')
            plt.plot(trade.step-1, price_at_trade, "rD")

        elif profit >= 0:
            wins +=1
            color = '#2ca02c'
            plt.axvspan(the_buy_step.step-1, trade.step-1, alpha= 0.1, facecolor='green')
            plt.plot(trade.step-1, price_at_trade, "gD")

ax2 = plt.subplot(212, sharex=ax)
exchange.performance.net_worth.plot()

# %%
"Win rate {}%".format(round(wins - losses / len(exchange.trades)), 2)
# Out:
# 'Win rate 66%'

# %%
import visualize

visualize.plot_stats(stats, ylog=False, view=True)

# %%
visualize.plot_species(stats, view=True)

# %%
visualize.draw_net(strategy._config, winner, False)

# %% [markdown]
# **Save Strategy**

# %%
import pickle
# winner.key
with open("winners/winner-{}.bin".format(winner.key), "wb") as f:
    pickle.dump(winner, f, 2)

# %%
    from math import log
1+ log(1 +( abs(22000 - 10000) ))
# Out:
# 10.392745258631441
